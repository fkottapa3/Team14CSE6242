# %%
# Updated March 22, 2025

# %% [markdown]
# # 1. Import Libraries

# %%
# ''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
#  1. Import libraries
# ''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix, classification_report
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE
import warnings
import xgboost as xgb
from sklearn.model_selection import GridSearchCV, StratifiedKFold, train_test_split
from xgboost.callback import EarlyStopping
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
warnings.filterwarnings("ignore")

# %% [markdown]
# # 2. Data loading

# %%
# ''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
#  2. Data loading
# ''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
file_path = os.path.join("C:/Users/USSB697670/Desktop/GeorgiaTech/Data_Visual_Analytics/Project", "diabetes_prediction_dataset.csv")
df = pd.read_csv(file_path)

print(f"Dataset Shape: {df.shape}")
print(f"Missing Values:\n{df.isnull().sum()}")
print(f"Duplicate Rows: {df.duplicated().sum()}")


df.head()
# Out:
# Dataset Shape: (100000, 9)
# Missing Values:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# smoking_history        0
# bmi                    0
# HbA1c_level            0
# blood_glucose_level    0
# diabetes               0
# dtype: int64
# Duplicate Rows: 3854
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0  Female  80.0             0              1           never  25.19
# 1  Female  54.0             0              0         No Info  27.32
# 2    Male  28.0             0              0           never  27.32
# 3  Female  36.0             0              0         current  23.45
# 4    Male  76.0             1              1         current  20.14
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          6.6                   80         0
# 2          5.7                  158         0
# 3          5.0                  155         0
# 4          4.8                  155         0

# %% [markdown]
# # 3. Data cleaning & Encoding

# %% [markdown]
# **check for duplicates**

# %%
# ''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
#  3. Data Cleaning
# ''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''''
duplicate_rows = df[df.duplicated()]
display(duplicate_rows.head(10))
df = df.drop_duplicates().reset_index(drop=True)
print(f"Dataset Shape After Removing Duplicates: {df.shape}")
# Out:
#       gender   age  hypertension  heart_disease smoking_history    bmi  \
# 2756    Male  80.0             0              0         No Info  27.32
# 3272  Female  80.0             0              0         No Info  27.32
# 3418  Female  19.0             0              0         No Info  27.32
# 3939  Female  78.0             1              0          former  27.32
# 3960    Male  47.0             0              0         No Info  27.32
# 4106  Female  51.0             0              0         No Info  27.32
# 4128  Female  80.0             0              0           never  27.32
# 4224    Male  80.0             1              0          former  27.32
# 4263    Male  80.0             0              0         No Info  27.32
# 4486    Male  50.0             0              0         No Info  27.32
#
#       HbA1c_level  blood_glucose_level  diabetes
# 2756          6.6                  159         0
# 3272          3.5                   80         0
# 3418          6.5                  100         0
# 3939          3.5                  130         0
# 3960          6.0                  200         0
# 4106          6.6                  200         0
# 4128          5.7                   85         0
# 4224          6.2                  130         0
# 4263          6.0                  100         0
# 4486          4.8                  155         0
# Dataset Shape After Removing Duplicates: (96146, 9)

# %% [markdown]
# Checking missing value

# %%
# print(df.isnull().sum())
sns.countplot(x=df['diabetes'], data=df)
plt.title('Distribution of Diabetes Outcomes')
plt.xlabel('Outcome')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Label Encoder

# %% [markdown]
# **Review the categorical variables**
#  - **if needed, we will use label encoding**

# %%
# Check unique values for 'gender'
print("Unique values in 'gender':", df['gender'].unique())

# Check unique values for 'smoking_history'
print("Unique values in 'smoking_history':", df['smoking_history'].unique())
# Out:
# Unique values in 'gender': ['Female' 'Male' 'Other']
# Unique values in 'smoking_history': ['never' 'No Info' 'current' 'former' 'ever' 'not current']

# %%
df = df[df["smoking_history"]!="No Info"].reset_index(drop=True)

# %%
print("Unique values in 'smoking_history':", df['smoking_history'].unique())
# Out:
# Unique values in 'smoking_history': ['never' 'current' 'former' 'ever' 'not current']

# %%
df["smoking_history"] = df["smoking_history"].replace("not current", "former")

# %% [markdown]
# **Since Gender has 3 values, we can keep the Label encoding as-is**
# **However, smoking_history has 4 values, so we will use one-hot encoding**

# %%
# Encode 'gender'
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['gender'] = le.fit_transform(df['gender'])

# %%
df.head()
# Out:
#    gender   age  hypertension  heart_disease smoking_history    bmi  \
# 0       0  80.0             0              1           never  25.19
# 1       1  28.0             0              0           never  27.32
# 2       0  36.0             0              0         current  23.45
# 3       1  76.0             1              1         current  20.14
# 4       0  20.0             0              0           never  27.32
#
#    HbA1c_level  blood_glucose_level  diabetes
# 0          6.6                  140         0
# 1          5.7                  158         0
# 2          5.0                  155         0
# 3          4.8                  155         0
# 4          6.6                   85         0

# %%
df1 = df.copy()
df['smoking_history'] = le.fit_transform(df['smoking_history'])

# %% [markdown]
# # 4. Feature Engineering

# %%
from sklearn.ensemble import ExtraTreesClassifier

# Define Features and Target variables
X = df.drop('diabetes', axis=1)
y = df['diabetes']

# Train ExtraTreesClassifier to identify feature importance
model = ExtraTreesClassifier()
model.fit(X, y)
# Get feature importances
importances = model.feature_importances_
# Create a DataFrame for better visualization
feat_importances = pd.DataFrame({'Feature': X.columns, 'Importance': importances})
# Sort the DataFrame by importance
feat_importances = feat_importances.sort_values(by='Importance', ascending=False)
# Plot the feature importances
plt.figure(figsize=(10, 6))
sns.barplot(x='Importance', y='Feature', data=feat_importances)
plt.title('Feature Importances from ExtraTreesClassifier')
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.show()

# %% [markdown]
# **One hot encoding for smoking_history**

# %%
# Encode 'smoking_history' using one hot encoding
df_encoded = pd.get_dummies(df1, columns=['smoking_history'])
df_encoded = df_encoded.astype(int)

# %%
df_encoded
# Out:
#        gender  age  hypertension  heart_disease  bmi  HbA1c_level  \
# 0           0   80             0              1   25            6
# 1           1   28             0              0   27            5
# 2           0   36             0              0   23            5
# 3           1   76             1              1   20            4
# 4           0   20             0              0   27            6
# ...       ...  ...           ...            ...  ...          ...
# 63254       0   26             0              0   34            6
# 63255       0   40             0              0   40            3
# 63256       1   66             0              0   27            5
# 63257       0   24             0              0   35            4
# 63258       0   57             0              0   22            6
#
#        blood_glucose_level  diabetes  smoking_history_current  \
# 0                      140         0                        0
# 1                      158         0                        0
# 2                      155         0                        1
# 3                      155         0                        1
# 4                       85         0                        0
# ...                    ...       ...                      ...
# 63254                  160         0                        0
# 63255                  155         0                        0
# 63256                  155         0                        0
# 63257                  100         0                        0
# 63258                   90         0                        1
#
#        smoking_history_ever  smoking_history_former  smoking_history_never
# 0                         0                       0                      1
# 1                         0                       0                      1
# 2                         0                       0                      0
# 3                         0                       0                      0
# 4                         0                       0                      1
# ...                     ...                     ...                    ...
# 63254                     0                       0                      1
# 63255                     0                       0                      1
# 63256                     0                       1                      0
# 63257                     0                       0                      1
# 63258                     0                       0                      0
#
# [63259 rows x 12 columns]

# %% [markdown]
# # 5. Database setup for comparative analysis

# %%
import sqlite3

# Connect to SQLite database (creates if it doesn’t exist)
conn = sqlite3.connect("diabetes_results.db")
cursor = conn.cursor()

# Drop the existing table (WARNING: This will delete all previous results)
cursor.execute("DROP TABLE IF EXISTS model_results")


# Create table for storing model results
cursor.execute("""
    CREATE TABLE IF NOT EXISTS model_results (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        model_name TEXT,
        data_type TEXT,
        threshold REAL,
        precision REAL,
        recall REAL,
        f1_score REAL,
        accuracy REAL,
        run_timestamp DATETIME DEFAULT CURRENT_TIMESTAMP
    )
""")
conn.commit()
conn.close()

# %% [markdown]
# **utility function to store model reports into db table**

# %%
import sqlite3
from sklearn.metrics import classification_report

def store_classification_results(model_name, data_type, threshold, y_true, y_pred):
    """Extract classification metrics and store them in SQLite"""
    
    report = classification_report(y_true, y_pred, output_dict=True)
    
    # Extract key metrics
    precision = report["1"]["precision"]
    recall = report["1"]["recall"]
    f1_score = report["1"]["f1-score"]
    accuracy = report["accuracy"]
    
    # Store in SQLite database
    conn = sqlite3.connect("diabetes_results.db")
    cursor = conn.cursor()

    # Check if this model run already exists
    cursor.execute("""
        SELECT COUNT(*) FROM model_results
        WHERE model_name = ? AND data_type = ? AND threshold = ? AND precision = ? AND recall = ? AND accuracy = ?
    """, (model_name, data_type, threshold, precision, recall, accuracy))

    cursor.execute("""
        INSERT INTO model_results (model_name, data_type, threshold, precision, recall, f1_score, accuracy)
        VALUES (?, ?, ?, ?, ?, ?, ?)
    """, (model_name, data_type, threshold, precision, recall, f1_score, accuracy))
    
    conn.commit()
    conn.close()
    
    print(f"Results stored successfully: {model_name} (Threshold: {threshold})")

# %% [markdown]
# **Feature Selection**

# %%
# Keep all features for visualization & dashboard interaction
X_full = df_encoded.drop(columns=["diabetes"])  # Keeps everything except the target variable

# Optimized feature set (for model training)
selected_features = ["HbA1c_level", "blood_glucose_level", "bmi", "age", "hypertension", "heart_disease", "smoking_history_current", "smoking_history_ever", "smoking_history_former", "smoking_history_never"  ]
X_selected = df_encoded[selected_features]

# Target variable remains the same
y = df_encoded["diabetes"]

# %% [markdown]
# Splitting Data

# %%
# We use StratifiedFold so that each fold in x-validation has the same proportion of diabetic and non-diabetic cases as the original dataset. 
# Also ensure balanced class distribution in each fold.
# Also find the best parameters while preventing overfitting
from sklearn.model_selection import StratifiedKFold
skf = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)

for train_idx, val_idx in skf.split(X_selected, y):
    X_train, X_test = X_selected.iloc[train_idx], X_selected.iloc[val_idx]
    y_train, y_test = y.iloc[train_idx], y.iloc[val_idx]

# %% [markdown]
# # 6. Feature Scaling and Normalization

# %% [markdown]
# - **Purpose: Feature scaling helps the model converge faster, ensures optimal performance and improves numerical stability.**
# - **Method: Standardization (Z-Score Normalization)**

# %%
from sklearn.preprocessing import StandardScaler
import pandas as pd
from sklearn.compose import ColumnTransformer

# Splitting the dataset into training and testing first
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X_selected, y, test_size=0.2, stratify=y, random_state=42
)


# Columns to scale
numeric_features = ["HbA1c_level", "blood_glucose_level", "bmi", "age"]

# Columns to leave unchanged
binary_features = [col for col in selected_features if col not in numeric_features]

# Create the ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ("num", StandardScaler(), numeric_features),
        ("bin", "passthrough", binary_features)
    ]
)

# Fitting scaler on training data only, then transforming both train and test data
X_train_scaled = preprocessor.fit_transform(X_train)
X_test_scaled = preprocessor.transform(X_test)

# Converting scaled data back to DataFrame for better interpretability
X_train_scaled = pd.DataFrame(X_train_scaled, columns=preprocessor.get_feature_names_out(), index=X_train.index)
X_test_scaled = pd.DataFrame(X_test_scaled, columns=preprocessor.get_feature_names_out(), index=X_test.index)

# Checking the results
X_train_scaled.head()
# Out:
#        num__HbA1c_level  num__blood_glucose_level  num__bmi  num__age  \
# 44099          0.735841                 -0.937847 -0.149670 -0.185402
# 40664         -0.151386                 -1.410502 -0.302184  1.709314
# 19520          0.735841                  0.007465  0.002845  0.070641
# 26218         -1.925841                  0.125629 -0.454699  1.658105
# 49952          0.735841                 -0.937847 -0.149670  1.350854
#
#        bin__hypertension  bin__heart_disease  bin__smoking_history_current  \
# 44099                0.0                 0.0                           0.0
# 40664                0.0                 0.0                           0.0
# 19520                1.0                 0.0                           1.0
# 26218                1.0                 0.0                           1.0
# 49952                0.0                 0.0                           0.0
#
#        bin__smoking_history_ever  bin__smoking_history_former  \
# 44099                        0.0                          1.0
# 40664                        0.0                          1.0
# 19520                        0.0                          0.0
# 26218                        0.0                          0.0
# 49952                        0.0                          0.0
#
#        bin__smoking_history_never
# 44099                         0.0
# 40664                         0.0
# 19520                         0.0
# 26218                         0.0
# 49952                         1.0

# %% [markdown]
# # 7. Expolratory Data Analysis

# %%
# List of numerical columns to check for outliers
#columns_to_check = ['bmi', 'HbA1c_level', 'blood_glucose_level']

#removed bmi as it has many outliers
columns_to_check = ['HbA1c_level', 'blood_glucose_level']

# Plot box plots for each numerical column
plt.figure(figsize=(12, 6))
for i, col in enumerate(columns_to_check, 1):
    plt.subplot(1, len(columns_to_check), i)
    sns.boxplot(y=df1[col])
    plt.title(f"Box Plot of {col}")

plt.tight_layout()
plt.show()

# %%
# Visualize the distribution of the target variable
plt.figure(figsize=(6, 4))
ax = sns.countplot(x='diabetes', data=df1)

# Add value labels on top of each bar
for p in ax.patches:
    ax.annotate(f'{p.get_height()}', 
                (p.get_x() + p.get_width() / 2, p.get_height()), 
                ha='center', va='bottom', fontsize=12, fontweight='bold')

# Title and display
plt.title("Distribution of Diabetes")
plt.xlabel("Diabetes (0 = No, 1 = Yes)")
plt.ylabel("Count")
plt.show()

# Plot distributions of numerical features
numerical_cols = ['age', 'bmi', 'HbA1c_level', 'blood_glucose_level']

# Create subplots for each numerical column
plt.figure(figsize=(15, 10))
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(2, 2, i)
    ax = sns.histplot(df1[col], kde=True, bins=20)

    # Add value labels on bars
    for p in ax.patches:
        if p.get_height() > 0:  # Avoid annotating empty bins
            ax.annotate(f'{int(p.get_height())}', 
                        (p.get_x() + p.get_width() / 2, p.get_height()), 
                        ha='center', va='bottom', fontsize=10, fontweight='bold')

    plt.title(f'Distribution of {col}')

plt.tight_layout()
plt.show()

# %%
numeric_data = df1.select_dtypes(include=['number'])

# Compute the correlation matrix
corr_matrix = numeric_data.corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title("Correlation Matrix")
plt.show()

# %%
# Pairplot to visualize relationships between numerical columns
sns.pairplot(df1, hue='diabetes', vars=numerical_cols)
plt.show()

# %%
# Visualize gender distribution
def add_labels(ax):
    for p in ax.patches:
        ax.annotate(f'{int(p.get_height())}', 
                    (p.get_x() + p.get_width() / 2, p.get_height()), 
                    ha='center', va='bottom', fontsize=10, fontweight='bold')

# Visualize gender distribution with diabetes
plt.figure(figsize=(8, 6))
ax = sns.countplot(x='gender', data=df1, hue='diabetes')
add_labels(ax)  # Add labels
plt.title("Gender Distribution with Diabetes")
plt.show()

# %%
# Visualize smoking history distribution with diabetes
plt.figure(figsize=(10, 6))
ax = sns.countplot(x='smoking_history', data=df1, hue='diabetes')
add_labels(ax)  # Add labels
plt.title("Smoking History Distribution with Diabetes")
plt.xticks(rotation=45)
plt.show()

# %%
#Analyzing the Relationship Between Features and Target Variable

# Age vs Diabetes
plt.figure(figsize=(8, 6))
sns.boxplot(x='diabetes', y='age', data=df1)
plt.title("Age vs Diabetes")
plt.show()

# %%
# BMI vs Diabetes
plt.figure(figsize=(8, 6))
sns.boxplot(x='diabetes', y='bmi', data=df1)
plt.title("BMI vs Diabetes")
plt.show()

# %%
# HbA1c Level vs Diabetes
plt.figure(figsize=(8, 6))
sns.boxplot(x='diabetes', y='HbA1c_level', data=df1)
plt.title("HbA1c Level vs Diabetes")
plt.show()

# %%
# Blood Glucose Level vs Diabetes
plt.figure(figsize=(8, 6))
sns.boxplot(x='diabetes', y='blood_glucose_level', data=df1)
plt.title("Blood Glucose Level vs Diabetes")
plt.show()

# %%
# Pairwise relationships with diabetes using scatterplots
sns.pairplot(df1, hue='diabetes', markers='o', plot_kws={'alpha': 0.6})
plt.show()

# %% [markdown]
# # 8. Model Training

# %% [markdown]
# #### **1. Logistic Regression- Model Training**
# - **Purpose: Use as a baseline model for predicting diabetes risk.**
# - **Outcome: a basic performance benchmark, demonstrates how linear relationships affect diabetes prediction.**

# %%
# Model Selection

from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
from sklearn.metrics import classification_report, confusion_matrix


#Train Logistic Regression Model with scaled features
model_lr = LogisticRegression(random_state=42)
model_lr.fit(X_train_scaled, y_train)

#Evaluate and make predictions on test set
y_preds_test_lr = model_lr.predict(X_test_scaled)
store_classification_results("Logistic Regression (scaled)", "test", 0.50, y_test, y_preds_test_lr)

#Evaluate and make predictions on train set
y_preds_train_lr = model_lr.predict(X_train_scaled)
store_classification_results("Logistic Regression (scaled)", "train", 0.50, y_train, y_preds_train_lr)

# Model Performance Reports:
print("Model Performance on Test Set with Scaled Features:")
print(classification_report(y_test, y_preds_test_lr))
print("Confusion Matrix (Test Set):")
print(confusion_matrix(y_test, y_preds_test_lr))

print("\nModel Performance on Train Set with Scaled Features:")
print(classification_report(y_train, y_preds_train_lr))
print("Confusion Matrix (Train Set):")
print(confusion_matrix(y_train, y_preds_train_lr))
# Out:
# Results stored successfully: Logistic Regression (scaled) (Threshold: 0.5)
# Results stored successfully: Logistic Regression (scaled) (Threshold: 0.5)
# Model Performance on Test Set with Scaled Features:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97     11245
#            1       0.84      0.62      0.71      1407
#
#     accuracy                           0.94     12652
#    macro avg       0.90      0.80      0.84     12652
# weighted avg       0.94      0.94      0.94     12652
#
# Confusion Matrix (Test Set):
# [[11081   164]
#  [  536   871]]
#
# Model Performance on Train Set with Scaled Features:
#               precision    recall  f1-score   support
#
#            0       0.95      0.99      0.97     44977
#            1       0.86      0.62      0.72      5630
#
#     accuracy                           0.95     50607
#    macro avg       0.91      0.80      0.84     50607
# weighted avg       0.94      0.95      0.94     50607
#
# Confusion Matrix (Train Set):
# [[44411   566]
#  [ 2158  3472]]

# %% [markdown]
# **Test SMOTE with default threshold 0.50**

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

# Step 1: Apply SMOTE to the scaled training set and testing set
smote = SMOTE(sampling_strategy=0.5, random_state=42)
X_train_smote, y_train_smote = smote.fit_resample(X_train_scaled, y_train)
X_test_smote, y_test_smote = smote.fit_resample(X_test_scaled, y_test)

# Step 2: Train Logistic Regression with balanced, scaled data
model_smote = LogisticRegression(random_state=42)
model_smote.fit(X_train_smote, y_train_smote)

# Step 3: Evaluate and make predictions on scaled test set
y_preds_test_smote = model_smote.predict(X_test_scaled)
store_classification_results("Logistic Regression (SMOTE & scaled)", "test", 0.50, y_test, y_preds_test_smote)

# Step 4: Evaluate and make predictions on scaled train set
y_preds_train_smote = model_smote.predict(X_train_scaled)
store_classification_results("Logistic Regression (SMOTE & scaled)", "train", 0.50, y_train, y_preds_train_smote)

# Model Performance Reports:
print("Model Performance on Test Set (SMOTE & Scaled):")
print(classification_report(y_test, y_preds_test_smote))
print("Confusion Matrix (Test Set):")
print(confusion_matrix(y_test, y_preds_test_smote))

print("\nModel Performance on Train Set (SMOTE & Scaled):")
print(classification_report(y_train, y_preds_train_smote))
print("Confusion Matrix (Train Set):")
print(confusion_matrix(y_train, y_preds_train_smote))
# Out:
# Results stored successfully: Logistic Regression (SMOTE & scaled) (Threshold: 0.5)
# Results stored successfully: Logistic Regression (SMOTE & scaled) (Threshold: 0.5)
# Model Performance on Test Set (SMOTE & Scaled):
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95     11245
#            1       0.58      0.78      0.67      1407
#
#     accuracy                           0.91     12652
#    macro avg       0.78      0.85      0.81     12652
# weighted avg       0.93      0.91      0.92     12652
#
# Confusion Matrix (Test Set):
# [[10462   783]
#  [  313  1094]]
#
# Model Performance on Train Set (SMOTE & Scaled):
#               precision    recall  f1-score   support
#
#            0       0.97      0.93      0.95     44977
#            1       0.58      0.79      0.67      5630
#
#     accuracy                           0.91     50607
#    macro avg       0.78      0.86      0.81     50607
# weighted avg       0.93      0.91      0.92     50607
#
# Confusion Matrix (Train Set):
# [[41822  3155]
#  [ 1203  4427]]

# %%
import xgboost
print(xgboost.__version__)  # Should be >= 1.3.0
# Out:
# 3.0.0

# %% [markdown]
# #### **2. XGBoost- Model Training**
# - **Purpose: XGBoost is an advanced gradient boosting alg designed to handle complex interaction and non-linear relationships in structured data.**
# - **Outcome: Improved predictive accuracy and robustness compared with simpler models by capturing complex patterns and interactions among features**

# %%
import xgboost as xgb
from sklearn.metrics import classification_report, confusion_matrix, roc_auc_score
from sklearn.preprocessing import StandardScaler
import shap
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

dtrain = xgb.DMatrix(X_train_smote, label=y_train_smote)
dtest = xgb.DMatrix(X_test_smote, label=y_test_smote)

# Compute class weight ratio
scale_pos_weight = y_train_smote.value_counts()[0] / y_train_smote.value_counts()[1]

# Define XGBoost parameters
params = {
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
    'scale_pos_weight': scale_pos_weight,
    'learning_rate': 0.05,
    'max_depth': 5,
    'reg_alpha': 0.5,
    'reg_lambda': 2.0,
    'subsample': 0.7,
    'colsample_bytree': 0.7,
    'gamma': 0.1,
    'min_child_weight': 3,
    'seed': 42
}

# Train model with early stopping
evals = [(dtrain, 'train'), (dtest, 'eval')]
bst = xgb.train(
    params=params,
    dtrain=dtrain,
    num_boost_round=500,
    evals=evals,
    early_stopping_rounds=20,
    verbose_eval=True
)

# Predict test and train
y_preds_test = bst.predict(dtest)
y_preds_test_labels = (y_preds_test >= 0.50).astype(int)

y_preds_train = bst.predict(dtrain)
y_preds_train_labels = (y_preds_train >= 0.50).astype(int)

# Store classification results
store_classification_results("XGBoost (Default threshold 50)", "test", 0.50, y_test_smote, y_preds_test_labels)
store_classification_results("XGBoost (Default threshold 50)", "train", 0.50, y_train_smote, y_preds_train_labels)

# Compute AUC-ROC
roc_auc_test = roc_auc_score(y_test_smote, y_preds_test)
roc_auc_train = roc_auc_score(y_train_smote, y_preds_train)
print(f"Test AUC-ROC: {roc_auc_test:.4f}")
print(f"Train AUC-ROC: {roc_auc_train:.4f}")

# Print classification metrics
print("\nModel Performance on Test set:")
print(classification_report(y_test_smote, y_preds_test_labels))
print("Confusion Matrix (Test Set):")
print(confusion_matrix(y_test_smote, y_preds_test_labels))

print("\nModel Performance on Train set:")
print(classification_report(y_train_smote, y_preds_train_labels))
print("Confusion Matrix (Train Set):")
print(confusion_matrix(y_train_smote, y_preds_train_labels))

# Plot built-in feature importances (from booster)
importance_dict = bst.get_score(importance_type='weight')
importance_df = pd.DataFrame({
    'Feature': list(importance_dict.keys()),
    'Importance': list(importance_dict.values())
}).sort_values(by='Importance', ascending=True)

plt.figure(figsize=(10, 5))
plt.barh(importance_df['Feature'], importance_df['Importance'])
plt.title("XGBoost Feature Importance (by weight)")
plt.xlabel("Importance")
plt.ylabel("Feature")
plt.show()
# Out:
# [0]	train-logloss:0.66802	eval-logloss:0.66840
# [1]	train-logloss:0.64529	eval-logloss:0.64596
# [2]	train-logloss:0.62378	eval-logloss:0.62455
# [3]	train-logloss:0.60540	eval-logloss:0.60629
# [4]	train-logloss:0.58674	eval-logloss:0.58779
# [5]	train-logloss:0.56393	eval-logloss:0.56485
# [6]	train-logloss:0.54318	eval-logloss:0.54399
# [7]	train-logloss:0.52392	eval-logloss:0.52463
# [8]	train-logloss:0.50681	eval-logloss:0.50750
# [9]	train-logloss:0.49346	eval-logloss:0.49454
# [10]	train-logloss:0.48134	eval-logloss:0.48258
# [11]	train-logloss:0.46713	eval-logloss:0.46825
# [12]	train-logloss:0.45380	eval-logloss:0.45490
# [13]	train-logloss:0.44140	eval-logloss:0.44241
# [14]	train-logloss:0.43190	eval-logloss:0.43301
# [15]	train-logloss:0.42085	eval-logloss:0.42196
# [16]	train-logloss:0.40988	eval-logloss:0.41090
# [17]	train-logloss:0.40180	eval-logloss:0.40311
# [18]	train-logloss:0.39465	eval-logloss:0.39606
# [19]	train-logloss:0.38527	eval-logloss:0.38659
# [20]	train-logloss:0.37659	eval-logloss:0.37787
# [21]	train-logloss:0.36877	eval-logloss:0.37000
# [22]	train-logloss:0.36092	eval-logloss:0.36209
# [23]	train-logloss:0.35513	eval-logloss:0.35654
# [24]	train-logloss:0.34844	eval-logloss:0.34978
# [25]	train-logloss:0.34189	eval-logloss:0.34322
# [26]	train-logloss:0.33643	eval-logloss:0.33801
# [27]	train-logloss:0.33063	eval-logloss:0.33219
# [28]	train-logloss:0.32512	eval-logloss:0.32668
# [29]	train-logloss:0.31974	eval-logloss:0.32118
# [30]	train-logloss:0.31564	eval-logloss:0.31732
# [31]	train-logloss:0.31092	eval-logloss:0.31260
# [32]	train-logloss:0.30742	eval-logloss:0.30906
# [33]	train-logloss:0.30397	eval-logloss:0.30579
# [34]	train-logloss:0.30070	eval-logloss:0.30274
# [35]	train-logloss:0.29739	eval-logloss:0.29936
# [36]	train-logloss:0.29439	eval-logloss:0.29643
# [37]	train-logloss:0.29130	eval-logloss:0.29344
# [38]	train-logloss:0.28772	eval-logloss:0.28992
# [39]	train-logloss:0.28492	eval-logloss:0.28737
# [40]	train-logloss:0.28228	eval-logloss:0.28478
# [41]	train-logloss:0.27978	eval-logloss:0.28233
# [42]	train-logloss:0.27677	eval-logloss:0.27934
# [43]	train-logloss:0.27395	eval-logloss:0.27652
# [44]	train-logloss:0.27170	eval-logloss:0.27434
# [45]	train-logloss:0.26904	eval-logloss:0.27174
# [46]	train-logloss:0.26616	eval-logloss:0.26886
# [47]	train-logloss:0.26364	eval-logloss:0.26632
# [48]	train-logloss:0.26146	eval-logloss:0.26414
# [49]	train-logloss:0.25979	eval-logloss:0.26235
# [50]	train-logloss:0.25745	eval-logloss:0.25985
# [51]	train-logloss:0.25524	eval-logloss:0.25763
# [52]	train-logloss:0.25370	eval-logloss:0.25608
# [53]	train-logloss:0.25206	eval-logloss:0.25461
# [54]	train-logloss:0.25025	eval-logloss:0.25297
# [55]	train-logloss:0.24857	eval-logloss:0.25130
# [56]	train-logloss:0.24725	eval-logloss:0.25002
# [57]	train-logloss:0.24580	eval-logloss:0.24848
# [58]	train-logloss:0.24418	eval-logloss:0.24685
# [59]	train-logloss:0.24227	eval-logloss:0.24493
# [60]	train-logloss:0.24104	eval-logloss:0.24374
# [61]	train-logloss:0.24016	eval-logloss:0.24307
# [62]	train-logloss:0.23866	eval-logloss:0.24157
# [63]	train-logloss:0.23749	eval-logloss:0.24032
# [64]	train-logloss:0.23649	eval-logloss:0.23939
# [65]	train-logloss:0.23523	eval-logloss:0.23808
# [66]	train-logloss:0.23429	eval-logloss:0.23722
# [67]	train-logloss:0.23243	eval-logloss:0.23535
# [68]	train-logloss:0.23119	eval-logloss:0.23393
# [69]	train-logloss:0.23009	eval-logloss:0.23274
# [70]	train-logloss:0.22925	eval-logloss:0.23207
# [71]	train-logloss:0.22840	eval-logloss:0.23119
# [72]	train-logloss:0.22710	eval-logloss:0.22991
# [73]	train-logloss:0.22534	eval-logloss:0.22807
# [74]	train-logloss:0.22443	eval-logloss:0.22722
# [75]	train-logloss:0.22360	eval-logloss:0.22644
# [76]	train-logloss:0.22254	eval-logloss:0.22529
# [77]	train-logloss:0.22159	eval-logloss:0.22434
# [78]	train-logloss:0.22059	eval-logloss:0.22322
# [79]	train-logloss:0.21981	eval-logloss:0.22238
# [80]	train-logloss:0.21894	eval-logloss:0.22154
# [81]	train-logloss:0.21826	eval-logloss:0.22080
# [82]	train-logloss:0.21759	eval-logloss:0.22024
# [83]	train-logloss:0.21699	eval-logloss:0.21968
# [84]	train-logloss:0.21639	eval-logloss:0.21913
# [85]	train-logloss:0.21550	eval-logloss:0.21826
# [86]	train-logloss:0.21464	eval-logloss:0.21742
# [87]	train-logloss:0.21334	eval-logloss:0.21610
# [88]	train-logloss:0.21279	eval-logloss:0.21557
# [89]	train-logloss:0.21225	eval-logloss:0.21496
# [90]	train-logloss:0.21135	eval-logloss:0.21399
# [91]	train-logloss:0.21062	eval-logloss:0.21327
# [92]	train-logloss:0.21011	eval-logloss:0.21276
# [93]	train-logloss:0.20963	eval-logloss:0.21232
# [94]	train-logloss:0.20915	eval-logloss:0.21187
# [95]	train-logloss:0.20841	eval-logloss:0.21107
# [96]	train-logloss:0.20780	eval-logloss:0.21051
# [97]	train-logloss:0.20738	eval-logloss:0.21001
# [98]	train-logloss:0.20677	eval-logloss:0.20942
# [99]	train-logloss:0.20582	eval-logloss:0.20836
# [100]	train-logloss:0.20522	eval-logloss:0.20777
# [101]	train-logloss:0.20451	eval-logloss:0.20699
# [102]	train-logloss:0.20420	eval-logloss:0.20663
# [103]	train-logloss:0.20380	eval-logloss:0.20624
# [104]	train-logloss:0.20252	eval-logloss:0.20501
# [105]	train-logloss:0.20217	eval-logloss:0.20469
# [106]	train-logloss:0.20040	eval-logloss:0.20291
# [107]	train-logloss:0.19985	eval-logloss:0.20233
# [108]	train-logloss:0.19943	eval-logloss:0.20189
# [109]	train-logloss:0.19904	eval-logloss:0.20146
# [110]	train-logloss:0.19800	eval-logloss:0.20036
# [111]	train-logloss:0.19778	eval-logloss:0.20010
# [112]	train-logloss:0.19718	eval-logloss:0.19956
# [113]	train-logloss:0.19591	eval-logloss:0.19833
# [114]	train-logloss:0.19542	eval-logloss:0.19785
# [115]	train-logloss:0.19460	eval-logloss:0.19698
# [116]	train-logloss:0.19317	eval-logloss:0.19552
# [117]	train-logloss:0.19273	eval-logloss:0.19509
# [118]	train-logloss:0.19187	eval-logloss:0.19420
# [119]	train-logloss:0.19103	eval-logloss:0.19332
# [120]	train-logloss:0.19080	eval-logloss:0.19299
# [121]	train-logloss:0.19042	eval-logloss:0.19267
# [122]	train-logloss:0.18993	eval-logloss:0.19210
# [123]	train-logloss:0.18964	eval-logloss:0.19183
# [124]	train-logloss:0.18939	eval-logloss:0.19162
# [125]	train-logloss:0.18918	eval-logloss:0.19144
# [126]	train-logloss:0.18894	eval-logloss:0.19118
# [127]	train-logloss:0.18766	eval-logloss:0.18981
# [128]	train-logloss:0.18738	eval-logloss:0.18952
# [129]	train-logloss:0.18706	eval-logloss:0.18912
# [130]	train-logloss:0.18668	eval-logloss:0.18878
# [131]	train-logloss:0.18651	eval-logloss:0.18856
# [132]	train-logloss:0.18600	eval-logloss:0.18804
# [133]	train-logloss:0.18526	eval-logloss:0.18728
# [134]	train-logloss:0.18414	eval-logloss:0.18616
# [135]	train-logloss:0.18304	eval-logloss:0.18503
# [136]	train-logloss:0.18283	eval-logloss:0.18486
# [137]	train-logloss:0.18257	eval-logloss:0.18464
# [138]	train-logloss:0.18198	eval-logloss:0.18402
# [139]	train-logloss:0.18184	eval-logloss:0.18385
# [140]	train-logloss:0.18165	eval-logloss:0.18368
# [141]	train-logloss:0.18113	eval-logloss:0.18316
# [142]	train-logloss:0.18087	eval-logloss:0.18292
# [143]	train-logloss:0.18003	eval-logloss:0.18197
# [144]	train-logloss:0.17893	eval-logloss:0.18086
# [145]	train-logloss:0.17868	eval-logloss:0.18064
# [146]	train-logloss:0.17809	eval-logloss:0.18003
# [147]	train-logloss:0.17709	eval-logloss:0.17904
# [148]	train-logloss:0.17657	eval-logloss:0.17848
# [149]	train-logloss:0.17649	eval-logloss:0.17842
# [150]	train-logloss:0.17612	eval-logloss:0.17804
# [151]	train-logloss:0.17576	eval-logloss:0.17758
# [152]	train-logloss:0.17489	eval-logloss:0.17670
# [153]	train-logloss:0.17454	eval-logloss:0.17636
# [154]	train-logloss:0.17433	eval-logloss:0.17612
# [155]	train-logloss:0.17347	eval-logloss:0.17527
# [156]	train-logloss:0.17294	eval-logloss:0.17475
# [157]	train-logloss:0.17287	eval-logloss:0.17465
# [158]	train-logloss:0.17238	eval-logloss:0.17414
# [159]	train-logloss:0.17225	eval-logloss:0.17401
# [160]	train-logloss:0.17143	eval-logloss:0.17318
# [161]	train-logloss:0.17098	eval-logloss:0.17272
# [162]	train-logloss:0.17091	eval-logloss:0.17268
# [163]	train-logloss:0.17077	eval-logloss:0.17250
# [164]	train-logloss:0.17028	eval-logloss:0.17194
# [165]	train-logloss:0.16984	eval-logloss:0.17147
# [166]	train-logloss:0.16967	eval-logloss:0.17132
# [167]	train-logloss:0.16892	eval-logloss:0.17060
# [168]	train-logloss:0.16846	eval-logloss:0.17011
# [169]	train-logloss:0.16829	eval-logloss:0.16993
# [170]	train-logloss:0.16759	eval-logloss:0.16927
# [171]	train-logloss:0.16741	eval-logloss:0.16909
# [172]	train-logloss:0.16695	eval-logloss:0.16854
# [173]	train-logloss:0.16664	eval-logloss:0.16822
# [174]	train-logloss:0.16640	eval-logloss:0.16796
# [175]	train-logloss:0.16618	eval-logloss:0.16783
# [176]	train-logloss:0.16553	eval-logloss:0.16718
# [177]	train-logloss:0.16543	eval-logloss:0.16712
# [178]	train-logloss:0.16533	eval-logloss:0.16705
# [179]	train-logloss:0.16525	eval-logloss:0.16697
# [180]	train-logloss:0.16461	eval-logloss:0.16631
# [181]	train-logloss:0.16446	eval-logloss:0.16617
# [182]	train-logloss:0.16445	eval-logloss:0.16620
# [183]	train-logloss:0.16361	eval-logloss:0.16532
# [184]	train-logloss:0.16340	eval-logloss:0.16512
# [185]	train-logloss:0.16321	eval-logloss:0.16500
# [186]	train-logloss:0.16296	eval-logloss:0.16478
# [187]	train-logloss:0.16258	eval-logloss:0.16441
# [188]	train-logloss:0.16243	eval-logloss:0.16429
# [189]	train-logloss:0.16189	eval-logloss:0.16378
# [190]	train-logloss:0.16132	eval-logloss:0.16321
# [191]	train-logloss:0.16081	eval-logloss:0.16272
# [192]	train-logloss:0.16063	eval-logloss:0.16251
# [193]	train-logloss:0.16059	eval-logloss:0.16246
# [194]	train-logloss:0.16055	eval-logloss:0.16242
# [195]	train-logloss:0.15985	eval-logloss:0.16168
# [196]	train-logloss:0.15960	eval-logloss:0.16143
# [197]	train-logloss:0.15955	eval-logloss:0.16141
# [198]	train-logloss:0.15903	eval-logloss:0.16085
# [199]	train-logloss:0.15900	eval-logloss:0.16083
# [200]	train-logloss:0.15879	eval-logloss:0.16061
# [201]	train-logloss:0.15877	eval-logloss:0.16059
# [202]	train-logloss:0.15845	eval-logloss:0.16028
# [203]	train-logloss:0.15780	eval-logloss:0.15968
# [204]	train-logloss:0.15758	eval-logloss:0.15950
# [205]	train-logloss:0.15730	eval-logloss:0.15920
# [206]	train-logloss:0.15686	eval-logloss:0.15877
# [207]	train-logloss:0.15668	eval-logloss:0.15859
# [208]	train-logloss:0.15631	eval-logloss:0.15824
# [209]	train-logloss:0.15612	eval-logloss:0.15806
# [210]	train-logloss:0.15608	eval-logloss:0.15798
# [211]	train-logloss:0.15578	eval-logloss:0.15767
# [212]	train-logloss:0.15545	eval-logloss:0.15740
# [213]	train-logloss:0.15513	eval-logloss:0.15708
# [214]	train-logloss:0.15468	eval-logloss:0.15666
# [215]	train-logloss:0.15439	eval-logloss:0.15639
# [216]	train-logloss:0.15413	eval-logloss:0.15618
# [217]	train-logloss:0.15392	eval-logloss:0.15601
# [218]	train-logloss:0.15367	eval-logloss:0.15577
# [219]	train-logloss:0.15348	eval-logloss:0.15559
# [220]	train-logloss:0.15339	eval-logloss:0.15550
# [221]	train-logloss:0.15318	eval-logloss:0.15533
# [222]	train-logloss:0.15306	eval-logloss:0.15522
# [223]	train-logloss:0.15293	eval-logloss:0.15507
# [224]	train-logloss:0.15286	eval-logloss:0.15499
# [225]	train-logloss:0.15271	eval-logloss:0.15484
# [226]	train-logloss:0.15237	eval-logloss:0.15448
# [227]	train-logloss:0.15224	eval-logloss:0.15436
# [228]	train-logloss:0.15210	eval-logloss:0.15421
# [229]	train-logloss:0.15175	eval-logloss:0.15384
# [230]	train-logloss:0.15148	eval-logloss:0.15350
# [231]	train-logloss:0.15123	eval-logloss:0.15326
# [232]	train-logloss:0.15115	eval-logloss:0.15324
# [233]	train-logloss:0.15099	eval-logloss:0.15313
# [234]	train-logloss:0.15088	eval-logloss:0.15302
# [235]	train-logloss:0.15031	eval-logloss:0.15241
# [236]	train-logloss:0.15016	eval-logloss:0.15229
# [237]	train-logloss:0.15013	eval-logloss:0.15225
# [238]	train-logloss:0.14999	eval-logloss:0.15216
# [239]	train-logloss:0.14962	eval-logloss:0.15178
# [240]	train-logloss:0.14939	eval-logloss:0.15159
# [241]	train-logloss:0.14911	eval-logloss:0.15136
# [242]	train-logloss:0.14870	eval-logloss:0.15092
# [243]	train-logloss:0.14870	eval-logloss:0.15096
# [244]	train-logloss:0.14858	eval-logloss:0.15088
# [245]	train-logloss:0.14838	eval-logloss:0.15067
# [246]	train-logloss:0.14823	eval-logloss:0.15057
# [247]	train-logloss:0.14814	eval-logloss:0.15048
# [248]	train-logloss:0.14800	eval-logloss:0.15038
# [249]	train-logloss:0.14783	eval-logloss:0.15020
# [250]	train-logloss:0.14745	eval-logloss:0.14978
# [251]	train-logloss:0.14727	eval-logloss:0.14965
# [252]	train-logloss:0.14727	eval-logloss:0.14968
# [253]	train-logloss:0.14711	eval-logloss:0.14957
# [254]	train-logloss:0.14695	eval-logloss:0.14942
# [255]	train-logloss:0.14684	eval-logloss:0.14931
# [256]	train-logloss:0.14658	eval-logloss:0.14909
# [257]	train-logloss:0.14628	eval-logloss:0.14880
# [258]	train-logloss:0.14613	eval-logloss:0.14873
# [259]	train-logloss:0.14578	eval-logloss:0.14842
# [260]	train-logloss:0.14559	eval-logloss:0.14825
# [261]	train-logloss:0.14552	eval-logloss:0.14819
# [262]	train-logloss:0.14545	eval-logloss:0.14812
# [263]	train-logloss:0.14510	eval-logloss:0.14780
# [264]	train-logloss:0.14489	eval-logloss:0.14759
# [265]	train-logloss:0.14486	eval-logloss:0.14757
# [266]	train-logloss:0.14474	eval-logloss:0.14748
# [267]	train-logloss:0.14450	eval-logloss:0.14726
# [268]	train-logloss:0.14435	eval-logloss:0.14714
# [269]	train-logloss:0.14426	eval-logloss:0.14711
# [270]	train-logloss:0.14392	eval-logloss:0.14673
# [271]	train-logloss:0.14356	eval-logloss:0.14638
# [272]	train-logloss:0.14347	eval-logloss:0.14630
# [273]	train-logloss:0.14321	eval-logloss:0.14606
# [274]	train-logloss:0.14305	eval-logloss:0.14595
# [275]	train-logloss:0.14305	eval-logloss:0.14595
# [276]	train-logloss:0.14294	eval-logloss:0.14590
# [277]	train-logloss:0.14286	eval-logloss:0.14581
# [278]	train-logloss:0.14267	eval-logloss:0.14563
# [279]	train-logloss:0.14266	eval-logloss:0.14563
# [280]	train-logloss:0.14252	eval-logloss:0.14549
# [281]	train-logloss:0.14238	eval-logloss:0.14539
# [282]	train-logloss:0.14216	eval-logloss:0.14522
# [283]	train-logloss:0.14193	eval-logloss:0.14498
# [284]	train-logloss:0.14180	eval-logloss:0.14494
# [285]	train-logloss:0.14149	eval-logloss:0.14466
# [286]	train-logloss:0.14147	eval-logloss:0.14466
# [287]	train-logloss:0.14117	eval-logloss:0.14438
# [288]	train-logloss:0.14104	eval-logloss:0.14430
# [289]	train-logloss:0.14092	eval-logloss:0.14422
# [290]	train-logloss:0.14069	eval-logloss:0.14398
# [291]	train-logloss:0.14063	eval-logloss:0.14395
# [292]	train-logloss:0.14053	eval-logloss:0.14391
# [293]	train-logloss:0.14029	eval-logloss:0.14367
# [294]	train-logloss:0.14003	eval-logloss:0.14340
# [295]	train-logloss:0.13986	eval-logloss:0.14326
# [296]	train-logloss:0.13979	eval-logloss:0.14319
# [297]	train-logloss:0.13950	eval-logloss:0.14294
# [298]	train-logloss:0.13937	eval-logloss:0.14286
# [299]	train-logloss:0.13928	eval-logloss:0.14279
# [300]	train-logloss:0.13911	eval-logloss:0.14264
# [301]	train-logloss:0.13892	eval-logloss:0.14248
# [302]	train-logloss:0.13880	eval-logloss:0.14236
# [303]	train-logloss:0.13862	eval-logloss:0.14218
# [304]	train-logloss:0.13856	eval-logloss:0.14210
# [305]	train-logloss:0.13844	eval-logloss:0.14199
# [306]	train-logloss:0.13821	eval-logloss:0.14178
# [307]	train-logloss:0.13818	eval-logloss:0.14175
# [308]	train-logloss:0.13795	eval-logloss:0.14151
# [309]	train-logloss:0.13777	eval-logloss:0.14134
# [310]	train-logloss:0.13769	eval-logloss:0.14126
# [311]	train-logloss:0.13747	eval-logloss:0.14107
# [312]	train-logloss:0.13738	eval-logloss:0.14097
# [313]	train-logloss:0.13714	eval-logloss:0.14075
# [314]	train-logloss:0.13692	eval-logloss:0.14057
# [315]	train-logloss:0.13671	eval-logloss:0.14035
# [316]	train-logloss:0.13657	eval-logloss:0.14022
# [317]	train-logloss:0.13639	eval-logloss:0.14007
# [318]	train-logloss:0.13631	eval-logloss:0.14005
# [319]	train-logloss:0.13618	eval-logloss:0.13997
# [320]	train-logloss:0.13607	eval-logloss:0.13987
# [321]	train-logloss:0.13593	eval-logloss:0.13980
# [322]	train-logloss:0.13582	eval-logloss:0.13973
# [323]	train-logloss:0.13569	eval-logloss:0.13965
# [324]	train-logloss:0.13555	eval-logloss:0.13957
# [325]	train-logloss:0.13552	eval-logloss:0.13955
# [326]	train-logloss:0.13537	eval-logloss:0.13942
# [327]	train-logloss:0.13516	eval-logloss:0.13924
# [328]	train-logloss:0.13506	eval-logloss:0.13913
# [329]	train-logloss:0.13489	eval-logloss:0.13899
# [330]	train-logloss:0.13475	eval-logloss:0.13891
# [331]	train-logloss:0.13463	eval-logloss:0.13880
# [332]	train-logloss:0.13452	eval-logloss:0.13870
# [333]	train-logloss:0.13439	eval-logloss:0.13857
# [334]	train-logloss:0.13439	eval-logloss:0.13858
# [335]	train-logloss:0.13434	eval-logloss:0.13852
# [336]	train-logloss:0.13430	eval-logloss:0.13852
# [337]	train-logloss:0.13408	eval-logloss:0.13829
# [338]	train-logloss:0.13400	eval-logloss:0.13821
# [339]	train-logloss:0.13386	eval-logloss:0.13816
# [340]	train-logloss:0.13377	eval-logloss:0.13808
# [341]	train-logloss:0.13354	eval-logloss:0.13787
# [342]	train-logloss:0.13356	eval-logloss:0.13789
# [343]	train-logloss:0.13355	eval-logloss:0.13789
# [344]	train-logloss:0.13341	eval-logloss:0.13779
# [345]	train-logloss:0.13325	eval-logloss:0.13764
# [346]	train-logloss:0.13305	eval-logloss:0.13746
# [347]	train-logloss:0.13303	eval-logloss:0.13745
# [348]	train-logloss:0.13290	eval-logloss:0.13734
# [349]	train-logloss:0.13283	eval-logloss:0.13728
# [350]	train-logloss:0.13270	eval-logloss:0.13717
# [351]	train-logloss:0.13259	eval-logloss:0.13711
# [352]	train-logloss:0.13251	eval-logloss:0.13705
# [353]	train-logloss:0.13242	eval-logloss:0.13698
# [354]	train-logloss:0.13229	eval-logloss:0.13685
# [355]	train-logloss:0.13215	eval-logloss:0.13673
# [356]	train-logloss:0.13201	eval-logloss:0.13661
# [357]	train-logloss:0.13193	eval-logloss:0.13653
# [358]	train-logloss:0.13193	eval-logloss:0.13654
# [359]	train-logloss:0.13185	eval-logloss:0.13651
# [360]	train-logloss:0.13170	eval-logloss:0.13639
# [361]	train-logloss:0.13155	eval-logloss:0.13623
# [362]	train-logloss:0.13143	eval-logloss:0.13615
# [363]	train-logloss:0.13141	eval-logloss:0.13617
# [364]	train-logloss:0.13135	eval-logloss:0.13615
# [365]	train-logloss:0.13126	eval-logloss:0.13611
# [366]	train-logloss:0.13115	eval-logloss:0.13603
# [367]	train-logloss:0.13110	eval-logloss:0.13600
# [368]	train-logloss:0.13096	eval-logloss:0.13586
# [369]	train-logloss:0.13090	eval-logloss:0.13584
# [370]	train-logloss:0.13075	eval-logloss:0.13574
# [371]	train-logloss:0.13073	eval-logloss:0.13572
# [372]	train-logloss:0.13064	eval-logloss:0.13562
# [373]	train-logloss:0.13058	eval-logloss:0.13560
# [374]	train-logloss:0.13045	eval-logloss:0.13547
# [375]	train-logloss:0.13031	eval-logloss:0.13536
# [376]	train-logloss:0.13016	eval-logloss:0.13524
# [377]	train-logloss:0.13006	eval-logloss:0.13518
# [378]	train-logloss:0.12998	eval-logloss:0.13512
# [379]	train-logloss:0.12989	eval-logloss:0.13506
# [380]	train-logloss:0.12982	eval-logloss:0.13500
# [381]	train-logloss:0.12974	eval-logloss:0.13494
# [382]	train-logloss:0.12963	eval-logloss:0.13488
# [383]	train-logloss:0.12954	eval-logloss:0.13481
# [384]	train-logloss:0.12950	eval-logloss:0.13481
# [385]	train-logloss:0.12949	eval-logloss:0.13481
# [386]	train-logloss:0.12931	eval-logloss:0.13464
# [387]	train-logloss:0.12917	eval-logloss:0.13450
# [388]	train-logloss:0.12910	eval-logloss:0.13443
# [389]	train-logloss:0.12898	eval-logloss:0.13434
# [390]	train-logloss:0.12885	eval-logloss:0.13424
# [391]	train-logloss:0.12872	eval-logloss:0.13414
# [392]	train-logloss:0.12867	eval-logloss:0.13411
# [393]	train-logloss:0.12852	eval-logloss:0.13394
# [394]	train-logloss:0.12843	eval-logloss:0.13389
# [395]	train-logloss:0.12836	eval-logloss:0.13381
# [396]	train-logloss:0.12830	eval-logloss:0.13380
# [397]	train-logloss:0.12826	eval-logloss:0.13375
# [398]	train-logloss:0.12812	eval-logloss:0.13364
# [399]	train-logloss:0.12801	eval-logloss:0.13356
# [400]	train-logloss:0.12788	eval-logloss:0.13346
# [401]	train-logloss:0.12783	eval-logloss:0.13343
# [402]	train-logloss:0.12767	eval-logloss:0.13332
# [403]	train-logloss:0.12749	eval-logloss:0.13315
# [404]	train-logloss:0.12737	eval-logloss:0.13307
# [405]	train-logloss:0.12724	eval-logloss:0.13293
# [406]	train-logloss:0.12711	eval-logloss:0.13284
# [407]	train-logloss:0.12702	eval-logloss:0.13276
# [408]	train-logloss:0.12695	eval-logloss:0.13269
# [409]	train-logloss:0.12683	eval-logloss:0.13260
# [410]	train-logloss:0.12676	eval-logloss:0.13254
# [411]	train-logloss:0.12667	eval-logloss:0.13247
# [412]	train-logloss:0.12663	eval-logloss:0.13244
# [413]	train-logloss:0.12647	eval-logloss:0.13230
# [414]	train-logloss:0.12643	eval-logloss:0.13230
# [415]	train-logloss:0.12640	eval-logloss:0.13228
# [416]	train-logloss:0.12631	eval-logloss:0.13221
# [417]	train-logloss:0.12617	eval-logloss:0.13211
# [418]	train-logloss:0.12616	eval-logloss:0.13211
# [419]	train-logloss:0.12602	eval-logloss:0.13200
# [420]	train-logloss:0.12597	eval-logloss:0.13196
# [421]	train-logloss:0.12589	eval-logloss:0.13193
# [422]	train-logloss:0.12577	eval-logloss:0.13185
# [423]	train-logloss:0.12567	eval-logloss:0.13181
# [424]	train-logloss:0.12564	eval-logloss:0.13177
# [425]	train-logloss:0.12553	eval-logloss:0.13164
# [426]	train-logloss:0.12547	eval-logloss:0.13157
# [427]	train-logloss:0.12532	eval-logloss:0.13146
# [428]	train-logloss:0.12526	eval-logloss:0.13144
# [429]	train-logloss:0.12522	eval-logloss:0.13140
# [430]	train-logloss:0.12526	eval-logloss:0.13145
# [431]	train-logloss:0.12515	eval-logloss:0.13141
# [432]	train-logloss:0.12507	eval-logloss:0.13138
# [433]	train-logloss:0.12499	eval-logloss:0.13130
# [434]	train-logloss:0.12492	eval-logloss:0.13123
# [435]	train-logloss:0.12481	eval-logloss:0.13111
# [436]	train-logloss:0.12475	eval-logloss:0.13106
# [437]	train-logloss:0.12465	eval-logloss:0.13096
# [438]	train-logloss:0.12454	eval-logloss:0.13084
# [439]	train-logloss:0.12451	eval-logloss:0.13082
# [440]	train-logloss:0.12439	eval-logloss:0.13070
# [441]	train-logloss:0.12429	eval-logloss:0.13065
# [442]	train-logloss:0.12420	eval-logloss:0.13060
# [443]	train-logloss:0.12404	eval-logloss:0.13044
# [444]	train-logloss:0.12393	eval-logloss:0.13036
# [445]	train-logloss:0.12390	eval-logloss:0.13033
# [446]	train-logloss:0.12380	eval-logloss:0.13025
# [447]	train-logloss:0.12372	eval-logloss:0.13020
# [448]	train-logloss:0.12364	eval-logloss:0.13015
# [449]	train-logloss:0.12359	eval-logloss:0.13012
# [450]	train-logloss:0.12354	eval-logloss:0.13011
# [451]	train-logloss:0.12343	eval-logloss:0.13001
# [452]	train-logloss:0.12329	eval-logloss:0.12986
# [453]	train-logloss:0.12315	eval-logloss:0.12975
# [454]	train-logloss:0.12309	eval-logloss:0.12972
# [455]	train-logloss:0.12303	eval-logloss:0.12966
# [456]	train-logloss:0.12292	eval-logloss:0.12958
# [457]	train-logloss:0.12289	eval-logloss:0.12957
# [458]	train-logloss:0.12291	eval-logloss:0.12957
# [459]	train-logloss:0.12280	eval-logloss:0.12948
# [460]	train-logloss:0.12269	eval-logloss:0.12940
# [461]	train-logloss:0.12257	eval-logloss:0.12930
# [462]	train-logloss:0.12257	eval-logloss:0.12931
# [463]	train-logloss:0.12251	eval-logloss:0.12929
# [464]	train-logloss:0.12245	eval-logloss:0.12926
# [465]	train-logloss:0.12235	eval-logloss:0.12921
# [466]	train-logloss:0.12229	eval-logloss:0.12916
# [467]	train-logloss:0.12225	eval-logloss:0.12913
# [468]	train-logloss:0.12216	eval-logloss:0.12907
# [469]	train-logloss:0.12205	eval-logloss:0.12901
# [470]	train-logloss:0.12193	eval-logloss:0.12888
# [471]	train-logloss:0.12188	eval-logloss:0.12885
# [472]	train-logloss:0.12180	eval-logloss:0.12883
# [473]	train-logloss:0.12171	eval-logloss:0.12875
# [474]	train-logloss:0.12165	eval-logloss:0.12870
# [475]	train-logloss:0.12159	eval-logloss:0.12870
# [476]	train-logloss:0.12152	eval-logloss:0.12867
# [477]	train-logloss:0.12141	eval-logloss:0.12856
# [478]	train-logloss:0.12138	eval-logloss:0.12854
# [479]	train-logloss:0.12135	eval-logloss:0.12852
# [480]	train-logloss:0.12130	eval-logloss:0.12848
# [481]	train-logloss:0.12123	eval-logloss:0.12844
# [482]	train-logloss:0.12119	eval-logloss:0.12844
# [483]	train-logloss:0.12112	eval-logloss:0.12843
# [484]	train-logloss:0.12101	eval-logloss:0.12834
# [485]	train-logloss:0.12094	eval-logloss:0.12830
# [486]	train-logloss:0.12092	eval-logloss:0.12828
# [487]	train-logloss:0.12078	eval-logloss:0.12814
# [488]	train-logloss:0.12071	eval-logloss:0.12808
# [489]	train-logloss:0.12061	eval-logloss:0.12801
# [490]	train-logloss:0.12052	eval-logloss:0.12796
# [491]	train-logloss:0.12046	eval-logloss:0.12792
# [492]	train-logloss:0.12041	eval-logloss:0.12787
# [493]	train-logloss:0.12027	eval-logloss:0.12776
# [494]	train-logloss:0.12017	eval-logloss:0.12768
# [495]	train-logloss:0.12010	eval-logloss:0.12763
# [496]	train-logloss:0.12004	eval-logloss:0.12760
# [497]	train-logloss:0.11997	eval-logloss:0.12756
# [498]	train-logloss:0.11990	eval-logloss:0.12756
# [499]	train-logloss:0.11986	eval-logloss:0.12752
# Results stored successfully: XGBoost (Default threshold 50) (Threshold: 0.5)
# Results stored successfully: XGBoost (Default threshold 50) (Threshold: 0.5)
# Test AUC-ROC: 0.9881
# Train AUC-ROC: 0.9909
#
# Model Performance on Test set:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96     11245
#            1       0.91      0.92      0.92      5622
#
#     accuracy                           0.95     16867
#    macro avg       0.94      0.94      0.94     16867
# weighted avg       0.95      0.95      0.95     16867
#
# Confusion Matrix (Test Set):
# [[10759   486]
#  [  437  5185]]
#
# Model Performance on Train set:
#               precision    recall  f1-score   support
#
#            0       0.96      0.96      0.96     44977
#            1       0.93      0.93      0.93     22488
#
#     accuracy                           0.95     67465
#    macro avg       0.94      0.95      0.95     67465
# weighted avg       0.95      0.95      0.95     67465
#
# Confusion Matrix (Train Set):
# [[43312  1665]
#  [ 1633 20855]]

# %% [markdown]
# #### **3. Random Forest - Model Training**
# - **Purpose: combines multiple decision trees to improve stability, accuracy and reduce overfitting inherent in individual decision trees**
# - **Outcome: Improved accuracy and generalization compared to Logistic Regression. Useful for understanding feature importance and interactions**

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split, StratifiedKFold, cross_val_score
from sklearn.metrics import (
    classification_report, confusion_matrix, roc_auc_score, RocCurveDisplay
)
import matplotlib.pyplot as plt


# ======== STRATIFIED K-FOLD CROSS-VALIDATION (ON TRAINING DATA ONLY) ========
kfold = StratifiedKFold(n_splits=5, shuffle=True, random_state=42)
# rf_model = RandomForestClassifier(n_estimators=100, class_weight='balanced', random_state=42)
rf_model = RandomForestClassifier(
    n_estimators=100, 
    max_depth=5,  # Limit tree depth from 8 to 5 to to reduce overfitting
    min_samples_split=10,  # Reduce overfitting
    min_samples_leaf=3,  #added to reduce complexity
    max_leaf_nodes=50,  # Limit number of leaf nodes
    max_features='sqrt', # Use square root of features for each split
    class_weight='balanced', 
    random_state=42
)

cv_scores = cross_val_score(rf_model, X_train_smote, y_train_smote, cv=kfold, scoring='roc_auc')

print(f'Stratified K-Fold ROC AUC Scores: {cv_scores}')
print(f'Average ROC AUC: {cv_scores.mean():.4f}')

# ======== TRAIN RANDOM FOREST MODEL ========
rf_model.fit(X_train_smote, y_train_smote)

# Predict on train and test
y_train_pred_rf = rf_model.predict(X_train_smote)
y_test_pred_rf = rf_model.predict(X_test_smote)
y_train_proba_rf = rf_model.predict_proba(X_train_smote)[:, 1]
y_test_proba_rf = rf_model.predict_proba(X_test_smote)[:, 1]

# ========== TRAIN EVALUATION ==========
print("\nRANDOM FOREST - TRAIN SET EVALUATION:")
print(classification_report(y_train_smote, y_train_pred_rf))
print("Confusion Matrix:\n", confusion_matrix(y_train_smote, y_train_pred_rf))
print(f"ROC AUC Score: {roc_auc_score(y_train_smote, y_train_proba_rf):.4f}")
store_classification_results("Random Forest", "train", 0.50, y_train_smote, y_train_pred_rf)

# ========== TEST EVALUATION ==========
print("\nRANDOM FOREST - TEST SET EVALUATION:")
print(classification_report(y_test_smote, y_test_pred_rf))
print("Confusion Matrix:\n", confusion_matrix(y_test_smote, y_test_pred_rf))
print(f"ROC AUC Score: {roc_auc_score(y_test_smote, y_test_proba_rf):.4f}")
store_classification_results("Random Forest", "test", 0.50, y_test_smote, y_test_pred_rf)

# ========== ROC Curve ==========
RocCurveDisplay.from_estimator(rf_model, X_test_smote, y_test_smote)
plt.title("Random Forest ROC Curve (Test Set)")
plt.xlabel("False Positive Rate")
plt.ylabel("True Positive Rate")
plt.grid(True)
plt.show()
# Out:
# Stratified K-Fold ROC AUC Scores: [0.96462945 0.96347278 0.96650563 0.96261791 0.96271229]
# Average ROC AUC: 0.9640
#
# RANDOM FOREST - TRAIN SET EVALUATION:
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.92     44977
#            1       0.82      0.86      0.84     22488
#
#     accuracy                           0.89     67465
#    macro avg       0.87      0.88      0.88     67465
# weighted avg       0.89      0.89      0.89     67465
#
# Confusion Matrix:
#  [[40653  4324]
#  [ 3061 19427]]
# ROC AUC Score: 0.9646
# Results stored successfully: Random Forest (Threshold: 0.5)
#
# RANDOM FOREST - TEST SET EVALUATION:
#               precision    recall  f1-score   support
#
#            0       0.93      0.90      0.92     11245
#            1       0.81      0.87      0.84      5622
#
#     accuracy                           0.89     16867
#    macro avg       0.87      0.89      0.88     16867
# weighted avg       0.89      0.89      0.89     16867
#
# Confusion Matrix:
#  [[10125  1120]
#  [  710  4912]]
# ROC AUC Score: 0.9633
# Results stored successfully: Random Forest (Threshold: 0.5)

# %% [markdown]
# #### **4. Blend XGBoost & Logistic Regression - Model Training - for better performance**
# - **Purpose: The blending combines predictions from XGBoost and LR, to leverage strengths of both models for improved accuracy and stability**
# - **Outcome: Enhance predictive performance and generatliation by balancing complex relationships captured by XGBoost with linear approach of Logistic Regression**

# %%
params = {
    'objective': 'binary:logistic',
    'eval_metric': 'logloss',
    'scale_pos_weight': scale_pos_weight,
    'learning_rate': 0.05,
    'max_depth': 5,
    'reg_alpha': 0.5,
    'reg_lambda': 2.0,
    'subsample': 0.7,
    'colsample_bytree': 0.7,
    'gamma': 0.1,
    'min_child_weight': 3,
    'seed': 42
}
# Convert data into DMatrix format explicitly
dtrain = xgb.DMatrix(X_train_smote, label=y_train_smote)
dtest = xgb.DMatrix(X_test_smote, label=y_test_smote)

# Retrain using xgb.train with early stopping explicitly supported
model_xgboost_optimized = xgb.train(
    params=params,
    dtrain=dtrain,
    num_boost_round=500,
    evals=[(dtrain, 'train'), (dtest, 'eval')],
    early_stopping_rounds=20,
    verbose_eval=True
)

# Generate Optimized XGBoost Probabilities explicitly
xgb_train_preds = model_xgboost_optimized.predict(dtrain).reshape(-1, 1)
xgb_test_preds = model_xgboost_optimized.predict(dtest).reshape(-1, 1)




# ======= Train Logistic Regression Meta-Model =======
model_logreg = LogisticRegression(random_state=42)
model_logreg.fit(xgb_train_preds, y_train_smote)

# ======= Final Ensemble Predictions =======
y_preds_train_blend_labels = model_logreg.predict(xgb_train_preds)
y_preds_test_blend_labels = model_logreg.predict(xgb_test_preds)

# ======= Store Results =======
store_classification_results("XGBoost + Logistic Regression (optimized & scaled)", "train", 0.50, y_train_smote, y_preds_train_blend_labels)
store_classification_results("XGBoost + Logistic Regression (optimized & scaled)", "test", 0.50, y_test_smote, y_preds_test_blend_labels)

# ======= Evaluate Final Ensemble Model =======
roc_auc_test = roc_auc_score(y_test_smote, y_preds_test_blend_labels)
roc_auc_train = roc_auc_score(y_train_smote, y_preds_train_blend_labels)
print(f"Test AUC-ROC: {roc_auc_test:.4f}")
print(f"Train AUC-ROC: {roc_auc_train:.4f}")

print("\nBlended Model Performance on Test set:")
print(classification_report(y_test_smote, y_preds_test_blend_labels))
print("Confusion Matrix (Test Set):")
print(confusion_matrix(y_test_smote, y_preds_test_blend_labels))

print("\nBlended Model Performance on Train set:")
print(classification_report(y_train_smote, y_preds_train_blend_labels))
print("Confusion Matrix (Train Set):")
print(confusion_matrix(y_train_smote, y_preds_train_blend_labels))
# Out:
# [0]	train-logloss:0.66802	eval-logloss:0.66840
# [1]	train-logloss:0.64529	eval-logloss:0.64596
# [2]	train-logloss:0.62378	eval-logloss:0.62455
# [3]	train-logloss:0.60540	eval-logloss:0.60629
# [4]	train-logloss:0.58674	eval-logloss:0.58779
# [5]	train-logloss:0.56393	eval-logloss:0.56485
# [6]	train-logloss:0.54318	eval-logloss:0.54399
# [7]	train-logloss:0.52392	eval-logloss:0.52463
# [8]	train-logloss:0.50681	eval-logloss:0.50750
# [9]	train-logloss:0.49346	eval-logloss:0.49454
# [10]	train-logloss:0.48134	eval-logloss:0.48258
# [11]	train-logloss:0.46713	eval-logloss:0.46825
# [12]	train-logloss:0.45380	eval-logloss:0.45490
# [13]	train-logloss:0.44140	eval-logloss:0.44241
# [14]	train-logloss:0.43190	eval-logloss:0.43301
# [15]	train-logloss:0.42085	eval-logloss:0.42196
# [16]	train-logloss:0.40988	eval-logloss:0.41090
# [17]	train-logloss:0.40180	eval-logloss:0.40311
# [18]	train-logloss:0.39465	eval-logloss:0.39606
# [19]	train-logloss:0.38527	eval-logloss:0.38659
# [20]	train-logloss:0.37659	eval-logloss:0.37787
# [21]	train-logloss:0.36877	eval-logloss:0.37000
# [22]	train-logloss:0.36092	eval-logloss:0.36209
# [23]	train-logloss:0.35513	eval-logloss:0.35654
# [24]	train-logloss:0.34844	eval-logloss:0.34978
# [25]	train-logloss:0.34189	eval-logloss:0.34322
# [26]	train-logloss:0.33643	eval-logloss:0.33801
# [27]	train-logloss:0.33063	eval-logloss:0.33219
# [28]	train-logloss:0.32512	eval-logloss:0.32668
# [29]	train-logloss:0.31974	eval-logloss:0.32118
# [30]	train-logloss:0.31564	eval-logloss:0.31732
# [31]	train-logloss:0.31092	eval-logloss:0.31260
# [32]	train-logloss:0.30742	eval-logloss:0.30906
# [33]	train-logloss:0.30397	eval-logloss:0.30579
# [34]	train-logloss:0.30070	eval-logloss:0.30274
# [35]	train-logloss:0.29739	eval-logloss:0.29936
# [36]	train-logloss:0.29439	eval-logloss:0.29643
# [37]	train-logloss:0.29130	eval-logloss:0.29344
# [38]	train-logloss:0.28772	eval-logloss:0.28992
# [39]	train-logloss:0.28492	eval-logloss:0.28737
# [40]	train-logloss:0.28228	eval-logloss:0.28478
# [41]	train-logloss:0.27978	eval-logloss:0.28233
# [42]	train-logloss:0.27677	eval-logloss:0.27934
# [43]	train-logloss:0.27395	eval-logloss:0.27652
# [44]	train-logloss:0.27170	eval-logloss:0.27434
# [45]	train-logloss:0.26904	eval-logloss:0.27174
# [46]	train-logloss:0.26616	eval-logloss:0.26886
# [47]	train-logloss:0.26364	eval-logloss:0.26632
# [48]	train-logloss:0.26146	eval-logloss:0.26414
# [49]	train-logloss:0.25979	eval-logloss:0.26235
# [50]	train-logloss:0.25745	eval-logloss:0.25985
# [51]	train-logloss:0.25524	eval-logloss:0.25763
# [52]	train-logloss:0.25370	eval-logloss:0.25608
# [53]	train-logloss:0.25206	eval-logloss:0.25461
# [54]	train-logloss:0.25025	eval-logloss:0.25297
# [55]	train-logloss:0.24857	eval-logloss:0.25130
# [56]	train-logloss:0.24725	eval-logloss:0.25002
# [57]	train-logloss:0.24580	eval-logloss:0.24848
# [58]	train-logloss:0.24418	eval-logloss:0.24685
# [59]	train-logloss:0.24227	eval-logloss:0.24493
# [60]	train-logloss:0.24104	eval-logloss:0.24374
# [61]	train-logloss:0.24016	eval-logloss:0.24307
# [62]	train-logloss:0.23866	eval-logloss:0.24157
# [63]	train-logloss:0.23749	eval-logloss:0.24032
# [64]	train-logloss:0.23649	eval-logloss:0.23939
# [65]	train-logloss:0.23523	eval-logloss:0.23808
# [66]	train-logloss:0.23429	eval-logloss:0.23722
# [67]	train-logloss:0.23243	eval-logloss:0.23535
# [68]	train-logloss:0.23119	eval-logloss:0.23393
# [69]	train-logloss:0.23009	eval-logloss:0.23274
# [70]	train-logloss:0.22925	eval-logloss:0.23207
# [71]	train-logloss:0.22840	eval-logloss:0.23119
# [72]	train-logloss:0.22710	eval-logloss:0.22991
# [73]	train-logloss:0.22534	eval-logloss:0.22807
# [74]	train-logloss:0.22443	eval-logloss:0.22722
# [75]	train-logloss:0.22360	eval-logloss:0.22644
# [76]	train-logloss:0.22254	eval-logloss:0.22529
# [77]	train-logloss:0.22159	eval-logloss:0.22434
# [78]	train-logloss:0.22059	eval-logloss:0.22322
# [79]	train-logloss:0.21981	eval-logloss:0.22238
# [80]	train-logloss:0.21894	eval-logloss:0.22154
# [81]	train-logloss:0.21826	eval-logloss:0.22080
# [82]	train-logloss:0.21759	eval-logloss:0.22024
# [83]	train-logloss:0.21699	eval-logloss:0.21968
# [84]	train-logloss:0.21639	eval-logloss:0.21913
# [85]	train-logloss:0.21550	eval-logloss:0.21826
# [86]	train-logloss:0.21464	eval-logloss:0.21742
# [87]	train-logloss:0.21334	eval-logloss:0.21610
# [88]	train-logloss:0.21279	eval-logloss:0.21557
# [89]	train-logloss:0.21225	eval-logloss:0.21496
# [90]	train-logloss:0.21135	eval-logloss:0.21399
# [91]	train-logloss:0.21062	eval-logloss:0.21327
# [92]	train-logloss:0.21011	eval-logloss:0.21276
# [93]	train-logloss:0.20963	eval-logloss:0.21232
# [94]	train-logloss:0.20915	eval-logloss:0.21187
# [95]	train-logloss:0.20841	eval-logloss:0.21107
# [96]	train-logloss:0.20780	eval-logloss:0.21051
# [97]	train-logloss:0.20738	eval-logloss:0.21001
# [98]	train-logloss:0.20677	eval-logloss:0.20942
# [99]	train-logloss:0.20582	eval-logloss:0.20836
# [100]	train-logloss:0.20522	eval-logloss:0.20777
# [101]	train-logloss:0.20451	eval-logloss:0.20699
# [102]	train-logloss:0.20420	eval-logloss:0.20663
# [103]	train-logloss:0.20380	eval-logloss:0.20624
# [104]	train-logloss:0.20252	eval-logloss:0.20501
# [105]	train-logloss:0.20217	eval-logloss:0.20469
# [106]	train-logloss:0.20040	eval-logloss:0.20291
# [107]	train-logloss:0.19985	eval-logloss:0.20233
# [108]	train-logloss:0.19943	eval-logloss:0.20189
# [109]	train-logloss:0.19904	eval-logloss:0.20146
# [110]	train-logloss:0.19800	eval-logloss:0.20036
# [111]	train-logloss:0.19778	eval-logloss:0.20010
# [112]	train-logloss:0.19718	eval-logloss:0.19956
# [113]	train-logloss:0.19591	eval-logloss:0.19833
# [114]	train-logloss:0.19542	eval-logloss:0.19785
# [115]	train-logloss:0.19460	eval-logloss:0.19698
# [116]	train-logloss:0.19317	eval-logloss:0.19552
# [117]	train-logloss:0.19273	eval-logloss:0.19509
# [118]	train-logloss:0.19187	eval-logloss:0.19420
# [119]	train-logloss:0.19103	eval-logloss:0.19332
# [120]	train-logloss:0.19080	eval-logloss:0.19299
# [121]	train-logloss:0.19042	eval-logloss:0.19267
# [122]	train-logloss:0.18993	eval-logloss:0.19210
# [123]	train-logloss:0.18964	eval-logloss:0.19183
# [124]	train-logloss:0.18939	eval-logloss:0.19162
# [125]	train-logloss:0.18918	eval-logloss:0.19144
# [126]	train-logloss:0.18894	eval-logloss:0.19118
# [127]	train-logloss:0.18766	eval-logloss:0.18981
# [128]	train-logloss:0.18738	eval-logloss:0.18952
# [129]	train-logloss:0.18706	eval-logloss:0.18912
# [130]	train-logloss:0.18668	eval-logloss:0.18878
# [131]	train-logloss:0.18651	eval-logloss:0.18856
# [132]	train-logloss:0.18600	eval-logloss:0.18804
# [133]	train-logloss:0.18526	eval-logloss:0.18728
# [134]	train-logloss:0.18414	eval-logloss:0.18616
# [135]	train-logloss:0.18304	eval-logloss:0.18503
# [136]	train-logloss:0.18283	eval-logloss:0.18486
# [137]	train-logloss:0.18257	eval-logloss:0.18464
# [138]	train-logloss:0.18198	eval-logloss:0.18402
# [139]	train-logloss:0.18184	eval-logloss:0.18385
# [140]	train-logloss:0.18165	eval-logloss:0.18368
# [141]	train-logloss:0.18113	eval-logloss:0.18316
# [142]	train-logloss:0.18087	eval-logloss:0.18292
# [143]	train-logloss:0.18003	eval-logloss:0.18197
# [144]	train-logloss:0.17893	eval-logloss:0.18086
# [145]	train-logloss:0.17868	eval-logloss:0.18064
# [146]	train-logloss:0.17809	eval-logloss:0.18003
# [147]	train-logloss:0.17709	eval-logloss:0.17904
# [148]	train-logloss:0.17657	eval-logloss:0.17848
# [149]	train-logloss:0.17649	eval-logloss:0.17842
# [150]	train-logloss:0.17612	eval-logloss:0.17804
# [151]	train-logloss:0.17576	eval-logloss:0.17758
# [152]	train-logloss:0.17489	eval-logloss:0.17670
# [153]	train-logloss:0.17454	eval-logloss:0.17636
# [154]	train-logloss:0.17433	eval-logloss:0.17612
# [155]	train-logloss:0.17347	eval-logloss:0.17527
# [156]	train-logloss:0.17294	eval-logloss:0.17475
# [157]	train-logloss:0.17287	eval-logloss:0.17465
# [158]	train-logloss:0.17238	eval-logloss:0.17414
# [159]	train-logloss:0.17225	eval-logloss:0.17401
# [160]	train-logloss:0.17143	eval-logloss:0.17318
# [161]	train-logloss:0.17098	eval-logloss:0.17272
# [162]	train-logloss:0.17091	eval-logloss:0.17268
# [163]	train-logloss:0.17077	eval-logloss:0.17250
# [164]	train-logloss:0.17028	eval-logloss:0.17194
# [165]	train-logloss:0.16984	eval-logloss:0.17147
# [166]	train-logloss:0.16967	eval-logloss:0.17132
# [167]	train-logloss:0.16892	eval-logloss:0.17060
# [168]	train-logloss:0.16846	eval-logloss:0.17011
# [169]	train-logloss:0.16829	eval-logloss:0.16993
# [170]	train-logloss:0.16759	eval-logloss:0.16927
# [171]	train-logloss:0.16741	eval-logloss:0.16909
# [172]	train-logloss:0.16695	eval-logloss:0.16854
# [173]	train-logloss:0.16664	eval-logloss:0.16822
# [174]	train-logloss:0.16640	eval-logloss:0.16796
# [175]	train-logloss:0.16618	eval-logloss:0.16783
# [176]	train-logloss:0.16553	eval-logloss:0.16718
# [177]	train-logloss:0.16543	eval-logloss:0.16712
# [178]	train-logloss:0.16533	eval-logloss:0.16705
# [179]	train-logloss:0.16525	eval-logloss:0.16697
# [180]	train-logloss:0.16461	eval-logloss:0.16631
# [181]	train-logloss:0.16446	eval-logloss:0.16617
# [182]	train-logloss:0.16445	eval-logloss:0.16620
# [183]	train-logloss:0.16361	eval-logloss:0.16532
# [184]	train-logloss:0.16340	eval-logloss:0.16512
# [185]	train-logloss:0.16321	eval-logloss:0.16500
# [186]	train-logloss:0.16296	eval-logloss:0.16478
# [187]	train-logloss:0.16258	eval-logloss:0.16441
# [188]	train-logloss:0.16243	eval-logloss:0.16429
# [189]	train-logloss:0.16189	eval-logloss:0.16378
# [190]	train-logloss:0.16132	eval-logloss:0.16321
# [191]	train-logloss:0.16081	eval-logloss:0.16272
# [192]	train-logloss:0.16063	eval-logloss:0.16251
# [193]	train-logloss:0.16059	eval-logloss:0.16246
# [194]	train-logloss:0.16055	eval-logloss:0.16242
# [195]	train-logloss:0.15985	eval-logloss:0.16168
# [196]	train-logloss:0.15960	eval-logloss:0.16143
# [197]	train-logloss:0.15955	eval-logloss:0.16141
# [198]	train-logloss:0.15903	eval-logloss:0.16085
# [199]	train-logloss:0.15900	eval-logloss:0.16083
# [200]	train-logloss:0.15879	eval-logloss:0.16061
# [201]	train-logloss:0.15877	eval-logloss:0.16059
# [202]	train-logloss:0.15845	eval-logloss:0.16028
# [203]	train-logloss:0.15780	eval-logloss:0.15968
# [204]	train-logloss:0.15758	eval-logloss:0.15950
# [205]	train-logloss:0.15730	eval-logloss:0.15920
# [206]	train-logloss:0.15686	eval-logloss:0.15877
# [207]	train-logloss:0.15668	eval-logloss:0.15859
# [208]	train-logloss:0.15631	eval-logloss:0.15824
# [209]	train-logloss:0.15612	eval-logloss:0.15806
# [210]	train-logloss:0.15608	eval-logloss:0.15798
# [211]	train-logloss:0.15578	eval-logloss:0.15767
# [212]	train-logloss:0.15545	eval-logloss:0.15740
# [213]	train-logloss:0.15513	eval-logloss:0.15708
# [214]	train-logloss:0.15468	eval-logloss:0.15666
# [215]	train-logloss:0.15439	eval-logloss:0.15639
# [216]	train-logloss:0.15413	eval-logloss:0.15618
# [217]	train-logloss:0.15392	eval-logloss:0.15601
# [218]	train-logloss:0.15367	eval-logloss:0.15577
# [219]	train-logloss:0.15348	eval-logloss:0.15559
# [220]	train-logloss:0.15339	eval-logloss:0.15550
# [221]	train-logloss:0.15318	eval-logloss:0.15533
# [222]	train-logloss:0.15306	eval-logloss:0.15522
# [223]	train-logloss:0.15293	eval-logloss:0.15507
# [224]	train-logloss:0.15286	eval-logloss:0.15499
# [225]	train-logloss:0.15271	eval-logloss:0.15484
# [226]	train-logloss:0.15237	eval-logloss:0.15448
# [227]	train-logloss:0.15224	eval-logloss:0.15436
# [228]	train-logloss:0.15210	eval-logloss:0.15421
# [229]	train-logloss:0.15175	eval-logloss:0.15384
# [230]	train-logloss:0.15148	eval-logloss:0.15350
# [231]	train-logloss:0.15123	eval-logloss:0.15326
# [232]	train-logloss:0.15115	eval-logloss:0.15324
# [233]	train-logloss:0.15099	eval-logloss:0.15313
# [234]	train-logloss:0.15088	eval-logloss:0.15302
# [235]	train-logloss:0.15031	eval-logloss:0.15241
# [236]	train-logloss:0.15016	eval-logloss:0.15229
# [237]	train-logloss:0.15013	eval-logloss:0.15225
# [238]	train-logloss:0.14999	eval-logloss:0.15216
# [239]	train-logloss:0.14962	eval-logloss:0.15178
# [240]	train-logloss:0.14939	eval-logloss:0.15159
# [241]	train-logloss:0.14911	eval-logloss:0.15136
# [242]	train-logloss:0.14870	eval-logloss:0.15092
# [243]	train-logloss:0.14870	eval-logloss:0.15096
# [244]	train-logloss:0.14858	eval-logloss:0.15088
# [245]	train-logloss:0.14838	eval-logloss:0.15067
# [246]	train-logloss:0.14823	eval-logloss:0.15057
# [247]	train-logloss:0.14814	eval-logloss:0.15048
# [248]	train-logloss:0.14800	eval-logloss:0.15038
# [249]	train-logloss:0.14783	eval-logloss:0.15020
# [250]	train-logloss:0.14745	eval-logloss:0.14978
# [251]	train-logloss:0.14727	eval-logloss:0.14965
# [252]	train-logloss:0.14727	eval-logloss:0.14968
# [253]	train-logloss:0.14711	eval-logloss:0.14957
# [254]	train-logloss:0.14695	eval-logloss:0.14942
# [255]	train-logloss:0.14684	eval-logloss:0.14931
# [256]	train-logloss:0.14658	eval-logloss:0.14909
# [257]	train-logloss:0.14628	eval-logloss:0.14880
# [258]	train-logloss:0.14613	eval-logloss:0.14873
# [259]	train-logloss:0.14578	eval-logloss:0.14842
# [260]	train-logloss:0.14559	eval-logloss:0.14825
# [261]	train-logloss:0.14552	eval-logloss:0.14819
# [262]	train-logloss:0.14545	eval-logloss:0.14812
# [263]	train-logloss:0.14510	eval-logloss:0.14780
# [264]	train-logloss:0.14489	eval-logloss:0.14759
# [265]	train-logloss:0.14486	eval-logloss:0.14757
# [266]	train-logloss:0.14474	eval-logloss:0.14748
# [267]	train-logloss:0.14450	eval-logloss:0.14726
# [268]	train-logloss:0.14435	eval-logloss:0.14714
# [269]	train-logloss:0.14426	eval-logloss:0.14711
# [270]	train-logloss:0.14392	eval-logloss:0.14673
# [271]	train-logloss:0.14356	eval-logloss:0.14638
# [272]	train-logloss:0.14347	eval-logloss:0.14630
# [273]	train-logloss:0.14321	eval-logloss:0.14606
# [274]	train-logloss:0.14305	eval-logloss:0.14595
# [275]	train-logloss:0.14305	eval-logloss:0.14595
# [276]	train-logloss:0.14294	eval-logloss:0.14590
# [277]	train-logloss:0.14286	eval-logloss:0.14581
# [278]	train-logloss:0.14267	eval-logloss:0.14563
# [279]	train-logloss:0.14266	eval-logloss:0.14563
# [280]	train-logloss:0.14252	eval-logloss:0.14549
# [281]	train-logloss:0.14238	eval-logloss:0.14539
# [282]	train-logloss:0.14216	eval-logloss:0.14522
# [283]	train-logloss:0.14193	eval-logloss:0.14498
# [284]	train-logloss:0.14180	eval-logloss:0.14494
# [285]	train-logloss:0.14149	eval-logloss:0.14466
# [286]	train-logloss:0.14147	eval-logloss:0.14466
# [287]	train-logloss:0.14117	eval-logloss:0.14438
# [288]	train-logloss:0.14104	eval-logloss:0.14430
# [289]	train-logloss:0.14092	eval-logloss:0.14422
# [290]	train-logloss:0.14069	eval-logloss:0.14398
# [291]	train-logloss:0.14063	eval-logloss:0.14395
# [292]	train-logloss:0.14053	eval-logloss:0.14391
# [293]	train-logloss:0.14029	eval-logloss:0.14367
# [294]	train-logloss:0.14003	eval-logloss:0.14340
# [295]	train-logloss:0.13986	eval-logloss:0.14326
# [296]	train-logloss:0.13979	eval-logloss:0.14319
# [297]	train-logloss:0.13950	eval-logloss:0.14294
# [298]	train-logloss:0.13937	eval-logloss:0.14286
# [299]	train-logloss:0.13928	eval-logloss:0.14279
# [300]	train-logloss:0.13911	eval-logloss:0.14264
# [301]	train-logloss:0.13892	eval-logloss:0.14248
# [302]	train-logloss:0.13880	eval-logloss:0.14236
# [303]	train-logloss:0.13862	eval-logloss:0.14218
# [304]	train-logloss:0.13856	eval-logloss:0.14210
# [305]	train-logloss:0.13844	eval-logloss:0.14199
# [306]	train-logloss:0.13821	eval-logloss:0.14178
# [307]	train-logloss:0.13818	eval-logloss:0.14175
# [308]	train-logloss:0.13795	eval-logloss:0.14151
# [309]	train-logloss:0.13777	eval-logloss:0.14134
# [310]	train-logloss:0.13769	eval-logloss:0.14126
# [311]	train-logloss:0.13747	eval-logloss:0.14107
# [312]	train-logloss:0.13738	eval-logloss:0.14097
# [313]	train-logloss:0.13714	eval-logloss:0.14075
# [314]	train-logloss:0.13692	eval-logloss:0.14057
# [315]	train-logloss:0.13671	eval-logloss:0.14035
# [316]	train-logloss:0.13657	eval-logloss:0.14022
# [317]	train-logloss:0.13639	eval-logloss:0.14007
# [318]	train-logloss:0.13631	eval-logloss:0.14005
# [319]	train-logloss:0.13618	eval-logloss:0.13997
# [320]	train-logloss:0.13607	eval-logloss:0.13987
# [321]	train-logloss:0.13593	eval-logloss:0.13980
# [322]	train-logloss:0.13582	eval-logloss:0.13973
# [323]	train-logloss:0.13569	eval-logloss:0.13965
# [324]	train-logloss:0.13555	eval-logloss:0.13957
# [325]	train-logloss:0.13552	eval-logloss:0.13955
# [326]	train-logloss:0.13537	eval-logloss:0.13942
# [327]	train-logloss:0.13516	eval-logloss:0.13924
# [328]	train-logloss:0.13506	eval-logloss:0.13913
# [329]	train-logloss:0.13489	eval-logloss:0.13899
# [330]	train-logloss:0.13475	eval-logloss:0.13891
# [331]	train-logloss:0.13463	eval-logloss:0.13880
# [332]	train-logloss:0.13452	eval-logloss:0.13870
# [333]	train-logloss:0.13439	eval-logloss:0.13857
# [334]	train-logloss:0.13439	eval-logloss:0.13858
# [335]	train-logloss:0.13434	eval-logloss:0.13852
# [336]	train-logloss:0.13430	eval-logloss:0.13852
# [337]	train-logloss:0.13408	eval-logloss:0.13829
# [338]	train-logloss:0.13400	eval-logloss:0.13821
# [339]	train-logloss:0.13386	eval-logloss:0.13816
# [340]	train-logloss:0.13377	eval-logloss:0.13808
# [341]	train-logloss:0.13354	eval-logloss:0.13787
# [342]	train-logloss:0.13356	eval-logloss:0.13789
# [343]	train-logloss:0.13355	eval-logloss:0.13789
# [344]	train-logloss:0.13341	eval-logloss:0.13779
# [345]	train-logloss:0.13325	eval-logloss:0.13764
# [346]	train-logloss:0.13305	eval-logloss:0.13746
# [347]	train-logloss:0.13303	eval-logloss:0.13745
# [348]	train-logloss:0.13290	eval-logloss:0.13734
# [349]	train-logloss:0.13283	eval-logloss:0.13728
# [350]	train-logloss:0.13270	eval-logloss:0.13717
# [351]	train-logloss:0.13259	eval-logloss:0.13711
# [352]	train-logloss:0.13251	eval-logloss:0.13705
# [353]	train-logloss:0.13242	eval-logloss:0.13698
# [354]	train-logloss:0.13229	eval-logloss:0.13685
# [355]	train-logloss:0.13215	eval-logloss:0.13673
# [356]	train-logloss:0.13201	eval-logloss:0.13661
# [357]	train-logloss:0.13193	eval-logloss:0.13653
# [358]	train-logloss:0.13193	eval-logloss:0.13654
# [359]	train-logloss:0.13185	eval-logloss:0.13651
# [360]	train-logloss:0.13170	eval-logloss:0.13639
# [361]	train-logloss:0.13155	eval-logloss:0.13623
# [362]	train-logloss:0.13143	eval-logloss:0.13615
# [363]	train-logloss:0.13141	eval-logloss:0.13617
# [364]	train-logloss:0.13135	eval-logloss:0.13615
# [365]	train-logloss:0.13126	eval-logloss:0.13611
# [366]	train-logloss:0.13115	eval-logloss:0.13603
# [367]	train-logloss:0.13110	eval-logloss:0.13600
# [368]	train-logloss:0.13096	eval-logloss:0.13586
# [369]	train-logloss:0.13090	eval-logloss:0.13584
# [370]	train-logloss:0.13075	eval-logloss:0.13574
# [371]	train-logloss:0.13073	eval-logloss:0.13572
# [372]	train-logloss:0.13064	eval-logloss:0.13562
# [373]	train-logloss:0.13058	eval-logloss:0.13560
# [374]	train-logloss:0.13045	eval-logloss:0.13547
# [375]	train-logloss:0.13031	eval-logloss:0.13536
# [376]	train-logloss:0.13016	eval-logloss:0.13524
# [377]	train-logloss:0.13006	eval-logloss:0.13518
# [378]	train-logloss:0.12998	eval-logloss:0.13512
# [379]	train-logloss:0.12989	eval-logloss:0.13506
# [380]	train-logloss:0.12982	eval-logloss:0.13500
# [381]	train-logloss:0.12974	eval-logloss:0.13494
# [382]	train-logloss:0.12963	eval-logloss:0.13488
# [383]	train-logloss:0.12954	eval-logloss:0.13481
# [384]	train-logloss:0.12950	eval-logloss:0.13481
# [385]	train-logloss:0.12949	eval-logloss:0.13481
# [386]	train-logloss:0.12931	eval-logloss:0.13464
# [387]	train-logloss:0.12917	eval-logloss:0.13450
# [388]	train-logloss:0.12910	eval-logloss:0.13443
# [389]	train-logloss:0.12898	eval-logloss:0.13434
# [390]	train-logloss:0.12885	eval-logloss:0.13424
# [391]	train-logloss:0.12872	eval-logloss:0.13414
# [392]	train-logloss:0.12867	eval-logloss:0.13411
# [393]	train-logloss:0.12852	eval-logloss:0.13394
# [394]	train-logloss:0.12843	eval-logloss:0.13389
# [395]	train-logloss:0.12836	eval-logloss:0.13381
# [396]	train-logloss:0.12830	eval-logloss:0.13380
# [397]	train-logloss:0.12826	eval-logloss:0.13375
# [398]	train-logloss:0.12812	eval-logloss:0.13364
# [399]	train-logloss:0.12801	eval-logloss:0.13356
# [400]	train-logloss:0.12788	eval-logloss:0.13346
# [401]	train-logloss:0.12783	eval-logloss:0.13343
# [402]	train-logloss:0.12767	eval-logloss:0.13332
# [403]	train-logloss:0.12749	eval-logloss:0.13315
# [404]	train-logloss:0.12737	eval-logloss:0.13307
# [405]	train-logloss:0.12724	eval-logloss:0.13293
# [406]	train-logloss:0.12711	eval-logloss:0.13284
# [407]	train-logloss:0.12702	eval-logloss:0.13276
# [408]	train-logloss:0.12695	eval-logloss:0.13269
# [409]	train-logloss:0.12683	eval-logloss:0.13260
# [410]	train-logloss:0.12676	eval-logloss:0.13254
# [411]	train-logloss:0.12667	eval-logloss:0.13247
# [412]	train-logloss:0.12663	eval-logloss:0.13244
# [413]	train-logloss:0.12647	eval-logloss:0.13230
# [414]	train-logloss:0.12643	eval-logloss:0.13230
# [415]	train-logloss:0.12640	eval-logloss:0.13228
# [416]	train-logloss:0.12631	eval-logloss:0.13221
# [417]	train-logloss:0.12617	eval-logloss:0.13211
# [418]	train-logloss:0.12616	eval-logloss:0.13211
# [419]	train-logloss:0.12602	eval-logloss:0.13200
# [420]	train-logloss:0.12597	eval-logloss:0.13196
# [421]	train-logloss:0.12589	eval-logloss:0.13193
# [422]	train-logloss:0.12577	eval-logloss:0.13185
# [423]	train-logloss:0.12567	eval-logloss:0.13181
# [424]	train-logloss:0.12564	eval-logloss:0.13177
# [425]	train-logloss:0.12553	eval-logloss:0.13164
# [426]	train-logloss:0.12547	eval-logloss:0.13157
# [427]	train-logloss:0.12532	eval-logloss:0.13146
# [428]	train-logloss:0.12526	eval-logloss:0.13144
# [429]	train-logloss:0.12522	eval-logloss:0.13140
# [430]	train-logloss:0.12526	eval-logloss:0.13145
# [431]	train-logloss:0.12515	eval-logloss:0.13141
# [432]	train-logloss:0.12507	eval-logloss:0.13138
# [433]	train-logloss:0.12499	eval-logloss:0.13130
# [434]	train-logloss:0.12492	eval-logloss:0.13123
# [435]	train-logloss:0.12481	eval-logloss:0.13111
# [436]	train-logloss:0.12475	eval-logloss:0.13106
# [437]	train-logloss:0.12465	eval-logloss:0.13096
# [438]	train-logloss:0.12454	eval-logloss:0.13084
# [439]	train-logloss:0.12451	eval-logloss:0.13082
# [440]	train-logloss:0.12439	eval-logloss:0.13070
# [441]	train-logloss:0.12429	eval-logloss:0.13065
# [442]	train-logloss:0.12420	eval-logloss:0.13060
# [443]	train-logloss:0.12404	eval-logloss:0.13044
# [444]	train-logloss:0.12393	eval-logloss:0.13036
# [445]	train-logloss:0.12390	eval-logloss:0.13033
# [446]	train-logloss:0.12380	eval-logloss:0.13025
# [447]	train-logloss:0.12372	eval-logloss:0.13020
# [448]	train-logloss:0.12364	eval-logloss:0.13015
# [449]	train-logloss:0.12359	eval-logloss:0.13012
# [450]	train-logloss:0.12354	eval-logloss:0.13011
# [451]	train-logloss:0.12343	eval-logloss:0.13001
# [452]	train-logloss:0.12329	eval-logloss:0.12986
# [453]	train-logloss:0.12315	eval-logloss:0.12975
# [454]	train-logloss:0.12309	eval-logloss:0.12972
# [455]	train-logloss:0.12303	eval-logloss:0.12966
# [456]	train-logloss:0.12292	eval-logloss:0.12958
# [457]	train-logloss:0.12289	eval-logloss:0.12957
# [458]	train-logloss:0.12291	eval-logloss:0.12957
# [459]	train-logloss:0.12280	eval-logloss:0.12948
# [460]	train-logloss:0.12269	eval-logloss:0.12940
# [461]	train-logloss:0.12257	eval-logloss:0.12930
# [462]	train-logloss:0.12257	eval-logloss:0.12931
# [463]	train-logloss:0.12251	eval-logloss:0.12929
# [464]	train-logloss:0.12245	eval-logloss:0.12926
# [465]	train-logloss:0.12235	eval-logloss:0.12921
# [466]	train-logloss:0.12229	eval-logloss:0.12916
# [467]	train-logloss:0.12225	eval-logloss:0.12913
# [468]	train-logloss:0.12216	eval-logloss:0.12907
# [469]	train-logloss:0.12205	eval-logloss:0.12901
# [470]	train-logloss:0.12193	eval-logloss:0.12888
# [471]	train-logloss:0.12188	eval-logloss:0.12885
# [472]	train-logloss:0.12180	eval-logloss:0.12883
# [473]	train-logloss:0.12171	eval-logloss:0.12875
# [474]	train-logloss:0.12165	eval-logloss:0.12870
# [475]	train-logloss:0.12159	eval-logloss:0.12870
# [476]	train-logloss:0.12152	eval-logloss:0.12867
# [477]	train-logloss:0.12141	eval-logloss:0.12856
# [478]	train-logloss:0.12138	eval-logloss:0.12854
# [479]	train-logloss:0.12135	eval-logloss:0.12852
# [480]	train-logloss:0.12130	eval-logloss:0.12848
# [481]	train-logloss:0.12123	eval-logloss:0.12844
# [482]	train-logloss:0.12119	eval-logloss:0.12844
# [483]	train-logloss:0.12112	eval-logloss:0.12843
# [484]	train-logloss:0.12101	eval-logloss:0.12834
# [485]	train-logloss:0.12094	eval-logloss:0.12830
# [486]	train-logloss:0.12092	eval-logloss:0.12828
# [487]	train-logloss:0.12078	eval-logloss:0.12814
# [488]	train-logloss:0.12071	eval-logloss:0.12808
# [489]	train-logloss:0.12061	eval-logloss:0.12801
# [490]	train-logloss:0.12052	eval-logloss:0.12796
# [491]	train-logloss:0.12046	eval-logloss:0.12792
# [492]	train-logloss:0.12041	eval-logloss:0.12787
# [493]	train-logloss:0.12027	eval-logloss:0.12776
# [494]	train-logloss:0.12017	eval-logloss:0.12768
# [495]	train-logloss:0.12010	eval-logloss:0.12763
# [496]	train-logloss:0.12004	eval-logloss:0.12760
# [497]	train-logloss:0.11997	eval-logloss:0.12756
# [498]	train-logloss:0.11990	eval-logloss:0.12756
# [499]	train-logloss:0.11986	eval-logloss:0.12752
# Results stored successfully: XGBoost + Logistic Regression (optimized & scaled) (Threshold: 0.5)
# Results stored successfully: XGBoost + Logistic Regression (optimized & scaled) (Threshold: 0.5)
# Test AUC-ROC: 0.9411
# Train AUC-ROC: 0.9444
#
# Blended Model Performance on Test set:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.96     11245
#            1       0.93      0.92      0.92      5622
#
#     accuracy                           0.95     16867
#    macro avg       0.95      0.94      0.94     16867
# weighted avg       0.95      0.95      0.95     16867
#
# Confusion Matrix (Test Set):
# [[10875   370]
#  [  477  5145]]
#
# Blended Model Performance on Train set:
#               precision    recall  f1-score   support
#
#            0       0.96      0.97      0.97     44977
#            1       0.94      0.92      0.93     22488
#
#     accuracy                           0.95     67465
#    macro avg       0.95      0.94      0.95     67465
# weighted avg       0.95      0.95      0.95     67465
#
# Confusion Matrix (Train Set):
# [[43756  1221]
#  [ 1890 20598]]

# %% [markdown]
# # Save models and scalars

# %%
# ======= Save the Ensemble Models and Scaler =======
import joblib

# Save the trained XGBoost booster model
model_xgboost_optimized.save_model("model_xgboost.json")

# Save the trained Logistic Regression model
joblib.dump(model_logreg, "model_logreg.pkl")

# Save the scaler used for preprocessing
joblib.dump(scaler, "scaler.pkl")

print("Models and scaler have been saved successfully.")
# Out:
# Models and scaler have been saved successfully.

# %% [markdown]
# **iwith emphasis on balancing bias and variance, we systematically optimized the hyperparameters using GridSearchCV and retrained the XGBoost model explicitly via the native API (xgb.train). This provided a robust solution with explicit early stopping, significantly enhancing model generalization and performance stability.**

# %% [markdown]
# # **TESTING**
#  - **Include all unit testing below**

# %%
df_encoded.describe
# Out:
# <bound method NDFrame.describe of        gender  age  hypertension  heart_disease  bmi  HbA1c_level  \
# 0           0   80             0              1   25            6
# 1           1   28             0              0   27            5
# 2           0   36             0              0   23            5
# 3           1   76             1              1   20            4
# 4           0   20             0              0   27            6
# ...       ...  ...           ...            ...  ...          ...
# 63254       0   26             0              0   34            6
# 63255       0   40             0              0   40            3
# 63256       1   66             0              0   27            5
# 63257       0   24             0              0   35            4
# 63258       0   57             0              0   22            6
#
#        blood_glucose_level  diabetes  smoking_history_current  \
# 0                      140         0                        0
# 1                      158         0                        0
# 2                      155         0                        1
# 3                      155         0                        1
# 4                       85         0                        0
# ...                    ...       ...                      ...
# 63254                  160         0                        0
# 63255                  155         0                        0
# 63256                  155         0                        0
# 63257                  100         0                        0
# 63258                   90         0                        1
#
#        smoking_history_ever  smoking_history_former  smoking_history_never
# 0                         0                       0                      1
# 1                         0                       0                      1
# 2                         0                       0                      0
# 3                         0                       0                      0
# 4                         0                       0                      1
# ...                     ...                     ...                    ...
# 63254                     0                       0                      1
# 63255                     0                       0                      1
# 63256                     0                       1                      0
# 63257                     0                       0                      1
# 63258                     0                       0                      0
#
# [63259 rows x 12 columns]>

# %%
df_encoded.info
# Out:
# <bound method DataFrame.info of        gender  age  hypertension  heart_disease  bmi  HbA1c_level  \
# 0           0   80             0              1   25            6
# 1           1   28             0              0   27            5
# 2           0   36             0              0   23            5
# 3           1   76             1              1   20            4
# 4           0   20             0              0   27            6
# ...       ...  ...           ...            ...  ...          ...
# 63254       0   26             0              0   34            6
# 63255       0   40             0              0   40            3
# 63256       1   66             0              0   27            5
# 63257       0   24             0              0   35            4
# 63258       0   57             0              0   22            6
#
#        blood_glucose_level  diabetes  smoking_history_current  \
# 0                      140         0                        0
# 1                      158         0                        0
# 2                      155         0                        1
# 3                      155         0                        1
# 4                       85         0                        0
# ...                    ...       ...                      ...
# 63254                  160         0                        0
# 63255                  155         0                        0
# 63256                  155         0                        0
# 63257                  100         0                        0
# 63258                   90         0                        1
#
#        smoking_history_ever  smoking_history_former  smoking_history_never
# 0                         0                       0                      1
# 1                         0                       0                      1
# 2                         0                       0                      0
# 3                         0                       0                      0
# 4                         0                       0                      1
# ...                     ...                     ...                    ...
# 63254                     0                       0                      1
# 63255                     0                       0                      1
# 63256                     0                       1                      0
# 63257                     0                       0                      1
# 63258                     0                       0                      0
#
# [63259 rows x 12 columns]>

# %%
import pandas as pd

# Load stored results into a DataFrame
conn = sqlite3.connect("diabetes_results.db")
df_results = pd.read_sql("SELECT * FROM model_results", conn)
conn.close()

# Display results
print(df_results)
# Out:
#    id                                         model_name data_type  threshold  \
# 0   1                       Logistic Regression (scaled)      test        0.5
# 1   2                       Logistic Regression (scaled)     train        0.5
# 2   3               Logistic Regression (SMOTE & scaled)      test        0.5
# 3   4               Logistic Regression (SMOTE & scaled)     train        0.5
# 4   5                     XGBoost (Default threshold 50)      test        0.5
# 5   6                     XGBoost (Default threshold 50)     train        0.5
# 6   7                                      Random Forest     train        0.5
# 7   8                                      Random Forest      test        0.5
# 8   9  XGBoost + Logistic Regression (optimized & sca...     train        0.5
# 9  10  XGBoost + Logistic Regression (optimized & sca...      test        0.5
#
#    precision    recall  f1_score  accuracy        run_timestamp
# 0   0.841546  0.619048  0.713350  0.944673  2025-04-08 23:19:29
# 1   0.859832  0.616696  0.718246  0.946173  2025-04-08 23:19:29
# 2   0.582845  0.777541  0.666261  0.913373  2025-04-08 23:19:31
# 3   0.583883  0.786323  0.670148  0.913885  2025-04-08 23:19:31
# 4   0.914301  0.922270  0.918268  0.945278  2025-04-08 23:19:35
# 5   0.926066  0.927383  0.926724  0.951115  2025-04-08 23:19:35
# 6   0.817945  0.863883  0.840286  0.890536  2025-04-08 23:19:45
# 7   0.814324  0.873710  0.842972  0.891504  2025-04-08 23:19:45
# 8   0.944040  0.915955  0.929785  0.953887  2025-04-08 23:22:02
# 9   0.932910  0.915155  0.923947  0.949784  2025-04-08 23:22:02

# %%
# Re-import necessary libraries
import sqlite3
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load stored results into separate DataFrames for test and train
conn = sqlite3.connect("diabetes_results.db")
df_results_test = pd.read_sql("SELECT * FROM model_results WHERE data_type = 'test'", conn)
df_results_train = pd.read_sql("SELECT * FROM model_results WHERE data_type = 'train'", conn)
conn.close()

# Set dark plot style
plt.style.use("dark_background")

# Define brighter colors explicitly
palette = {"precision": "#FF4500", "recall": "#32CD32", "accuracy": "#1E90FF"}

# Function to plot metrics for test and train data separately
def plot_metrics(df, title):
    plt.figure(figsize=(12, 6))
    
    # Reshape DataFrame for seaborn compatibility
    df_melted = df.melt(id_vars='model_name', value_vars=['precision', 'recall', 'accuracy'],
                        var_name='metric', value_name='score')
    
    sns.barplot(data=df_melted, x="model_name", y="score", hue="metric", palette=palette)
    
    # Customize the plot
    plt.xlabel("Model Name")
    plt.ylabel("Score")
    plt.xticks(rotation=20, ha="right")
    plt.title(title)
    plt.legend(title='Metrics', loc='lower right')

    # Show plot
    plt.show()

# Generate separate plots for Test and Train
plot_metrics(df_results_test, "Model Performance (Test Data)")
plot_metrics(df_results_train, "Model Performance (Train Data)")

# %% [markdown]
# **Legend**
#     -   **precision: higher the precision, the fewer the false alarms**
#     -   **recall: higher the recall, the model accurately identifies who are diabetic**

# %% [markdown]
# **Line plot for accuracy over Time**

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Convert timestamp to datetime
df_results['run_timestamp'] = pd.to_datetime(df_results['run_timestamp'])

# Sort by timestamp
df_results = df_results.sort_values(by='run_timestamp')

# Plot accuracy over time
plt.figure(figsize=(12, 6))
sns.lineplot(data=df_results, x="run_timestamp", y="accuracy", hue="model_name", style="data_type", marker="o")
plt.xticks(rotation=30, ha="right")
plt.xlabel("Run Timestamp")
plt.ylabel("Accuracy")
plt.title("Model Accuracy Over Time")
plt.legend(title="Model & Data Type", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.grid()
plt.show()

# %% [markdown]
# **Overfitting Analysis**

# %%
df_results_pivot = df_results.pivot(index=["model_name", "threshold"], columns="data_type", values="accuracy")
df_results_pivot["overfitting_score"] = df_results_pivot["train"] - df_results_pivot["test"]

# Display models with the highest overfitting scores
df_results_pivot.sort_values(by="overfitting_score", ascending=False)
# Out:
# data_type                                                         test  \
# model_name                                         threshold
# XGBoost (Default threshold 50)                     0.5        0.945278
# XGBoost + Logistic Regression (optimized & scaled) 0.5        0.949784
# Logistic Regression (scaled)                       0.5        0.944673
# Logistic Regression (SMOTE & scaled)               0.5        0.913373
# Random Forest                                      0.5        0.891504
#
# data_type                                                        train  \
# model_name                                         threshold
# XGBoost (Default threshold 50)                     0.5        0.951115
# XGBoost + Logistic Regression (optimized & scaled) 0.5        0.953887
# Logistic Regression (scaled)                       0.5        0.946173
# Logistic Regression (SMOTE & scaled)               0.5        0.913885
# Random Forest                                      0.5        0.890536
#
# data_type                                                     overfitting_score
# model_name                                         threshold
# XGBoost (Default threshold 50)                     0.5                 0.005838
# XGBoost + Logistic Regression (optimized & scaled) 0.5                 0.004104
# Logistic Regression (scaled)                       0.5                 0.001501
# Logistic Regression (SMOTE & scaled)               0.5                 0.000512
# Random Forest                                      0.5                -0.000968

# %% [markdown]
# **Visualize Overfitting Score using Bar Plot**

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 5))
sns.barplot(data=df_results_pivot.reset_index(), x="model_name", y="overfitting_score", hue="threshold", palette="viridis")
plt.xlabel("Model Name")
plt.ylabel("Overfitting Score (Train - Test Accuracy)")
plt.title("Overfitting Score by Model")
plt.xticks(rotation=20, ha="right")
plt.legend(title="Threshold")
plt.show()

plt.figure(figsize=(10, 6))
df_melted = df_results_pivot.reset_index().melt(id_vars=["model_name", "threshold"], 
                                                value_vars=["train", "test"],
                                                var_name="data_type", value_name="accuracy")

sns.barplot(data=df_melted, x="model_name", y="accuracy", hue="data_type", palette="coolwarm")
plt.xlabel("Model Name")
plt.ylabel("Accuracy")
plt.xticks(rotation=20, ha="right")
plt.title("Train vs Test Accuracy by Model")
plt.legend(title="Data Type")
plt.show()
